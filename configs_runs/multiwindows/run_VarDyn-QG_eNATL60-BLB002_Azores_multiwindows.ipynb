# %% [markdown]
# # Run Multi-Processing VarDyn Experiment

# %% [markdown]
# '../configs/config_VarDyn_extGulfstream_allsat-alg_1month_Jan-Jun.py'
#
# '../configs/config_VarDyn_extGulfstream_allsat-alg_1month_Jul-Dec.py'

# %% [markdown]
# ## Libraries

# %%
from datetime import datetime
import matplotlib.pyplot as plt
import sys
sys.path.append('/home/nora/VarDyn/mapping')
from src import exp, state, inv, diag
from src.run_assimilation import prepare_process, compute_weights_map, plot_subdomains, run_assimilation_time_window, merge_time_windows_outputs

import warnings
warnings.filterwarnings("ignore", category=UserWarning)

# %% [markdown]
# *** subwindow from 2019-01-01 00:00:00 to 2019-02-20 00:00:00 ***
#
# *** subwindow from 2019-02-10 00:00:00 to 2019-04-01 00:00:00 ***
#
# *** subwindow from 2019-03-22 00:00:00 to 2019-05-11 00:00:00 ***
#
# *** subwindow from 2019-05-01 00:00:00 to 2019-06-20 00:00:00 ***
#
# *** subwindow from 2019-06-10 00:00:00 to 2019-07-30 00:00:00 ***
#
# *** subwindow from 2019-07-20 00:00:00 to 2019-09-08 00:00:00 ***

# %% [markdown]
# ## Global parameters

# %%
path_config = '/home/nora/configs_VarDyn/multiwindows/config_VarDyn-QG_eNATL60-BLB002_Azores_multiwindows.py'

path_config_eq = '/home/nora/configs_VarDyn/multiwindows/config_VarDyn-QG_eNATL60-BLB002_Azores_multiwindows.py'

gpu_devices = ['1']

nprocs = 1

grid_type = 'GRID_CAR' # Type of grid. This is used to set the default values for the space window size and overlap  

space_window_size_proc_x = None # Space window size of one process in the x direction (degrees longitude) (Set to None for no split in space)

space_window_size_proc_y = None # Space window size of one process in the y direction (degrees latitude) (Set to None for no split in space)    

nx_proc = None # Number of grid points in the x direction for one process (only for GRID_CAR)

ny_proc = None # Number of grid points in the y direction for one process (only for GRID_CAR)

dx = dy = None # Grid spacing in km for one process (only for GRID_CAR)

space_overlap_x = None  # Absolute overlap in degrees (longitude) between successive space windows

space_overlap_y = None  # Absolute overlap in degrees (latitude) between successive space windows

time_window_size_proc = 50 # Time window size of one process (days). Set to None for no split in time.

time_overlap = 10  # Absolute overlap in days between successive time windows

JAX_mem_fraction = None

name_var_save = ['SSH_tot']

flag_init_from_previous = True

init_date = datetime(2009,7,11,0)    # datetime(2019,2,10,0) # datetime(2019,3,22,0)

final_date = datetime(2010,2,25,0)

flag_assim_restart = True

flag_assim = True

flag_merge_outputs = True

flag_diag = False

flag_overwrite_outputs = True

flag_test = False

flag_init_from_nadirs = False

name_exp_nadirs = '' # Name of the experiment for nadirs. This is used to use the output from the nadirs.

# %% [markdown]
# ## Configuration file

# %%
config = exp.Exp(path_config)
config_eq = exp.Exp(path_config)
# Out:
# name_experiment: VarDyn-QG_eNATL60-BLB002_Azores_multiwindows
# saveoutputs: True
# name_exp_save: VarDyn-QG_eNATL60-BLB002_Azores_multiwindows
# path_save: /data2/nora/Workdir/VarDyn/outputs/VarDyn-QG_eNATL60-BLB002_Azores_multiwindows
# tmp_DA_path: /data2/nora/Workdir/VarDyn/scratch/VarDyn-QG_eNATL60-BLB002_Azores_multiwindows
# init_date: 2009-07-11 00:00:00
# final_date: 2010-02-25 00:00:00
# assimilation_time_step: 6:00:00
# saveoutput_time_step: 6:00:00
# flag_plot: 0
# write_obs: True
# path_obs: /data2/nora/Workdir/VarDyn/obs
# compute_obs: False
# name_lon: lon
# name_lat: lat
# name_time: time
# plot_time_step: 1 day, 0:00:00
# time_obs_min: None
# time_obs_max: None
# lon_obs_min: None
# lon_obs_max: None
# lat_obs_min: None
# lat_obs_max: None
#
# name_experiment: VarDyn-QG_eNATL60-BLB002_Azores_multiwindows
# saveoutputs: True
# name_exp_save: VarDyn-QG_eNATL60-BLB002_Azores_multiwindows
# path_save: /data2/nora/Workdir/VarDyn/outputs/VarDyn-QG_eNATL60-BLB002_Azores_multiwindows
# tmp_DA_path: /data2/nora/Workdir/VarDyn/scratch/VarDyn-QG_eNATL60-BLB002_Azores_multiwindows
# init_date: 2009-07-11 00:00:00
# final_date: 2010-02-25 00:00:00
# assimilation_time_step: 6:00:00
# saveoutput_time_step: 6:00:00
# flag_plot: 0
# write_obs: True
# path_obs: /data2/nora/Workdir/VarDyn/obs
# compute_obs: False
# name_lon: lon
# name_lat: lat
# name_time: time
# plot_time_step: 1 day, 0:00:00
# time_obs_min: None
# time_obs_max: None
# lon_obs_min: None
# lon_obs_max: None
# lat_obs_min: None
# lat_obs_max: None

# %% [markdown]
# ## State

# %%
State = state.State(config)
plt.pcolormesh(State.lon,State.lat,State.mask)
# Out:
# super: GRID_GEO
# lon_min: -33
# lon_max: -23
# lat_min: 28
# lat_max: 38
# dlon: 0.1
# dlat: 0.1
# name_init_mask: /data1/data/models/eNATL60/BLB002/coarsened/eNATL60-BLB002_coarse-5_rolling-20.nc
# name_var_mask: {'lon': 'lon', 'lat': 'lat', 'var': 'ssh'}

# %% [markdown]
# ## Prepare Assimilation

# %% [markdown]
# #### Create subwindows

# %%
list_processes, list_config, list_State, list_date_start, list_date_end, list_date_middle, list_lonlat =\
      prepare_process(config, config_eq, State, 
                    init_date, final_date,
                    grid_type=grid_type,
                    nx_proc=nx_proc, ny_proc=ny_proc, dx=dx, dy=dy,
                    time_window_size_proc=time_window_size_proc, space_window_size_proc_x=space_window_size_proc_x, space_window_size_proc_y=space_window_size_proc_y, 
                    time_overlap=time_overlap, space_overlap_x=space_overlap_x, space_overlap_y=space_overlap_y,
                    flag_init_from_previous=flag_init_from_previous, flag_init=flag_init_from_nadirs, flag_background=False,
                    flag_assim=flag_assim, flag_assim_restart=flag_assim_restart,
                    name_exp_init=name_exp_nadirs, name_exp_background=name_exp_nadirs,
                    gpu_devices=gpu_devices)
# Out:
# 0 subwindow_2009-08-05/subwindow_-28_33
# 1 subwindow_2009-09-14/subwindow_-28_33
# 2 subwindow_2009-10-24/subwindow_-28_33
# 3 subwindow_2009-12-03/subwindow_-28_33
# 4 subwindow_2010-01-12/subwindow_-28_33
# 5 subwindow_2010-02-10/subwindow_-28_33

# %% [markdown]
# #### Compute weight maps

# %%
weights_space, weights_space_sum, interpolators = compute_weights_map(State, list_State)
plt.pcolormesh(weights_space_sum)
plt.colorbar()

# %% [markdown]
# #### Plot domains

# %%
lonlat_grid = [(State.lon,State.lat) for State in list_State[0]]
plot_subdomains(lonlat_grid)

# %% [markdown]
# ## Assimilation

# %%
idt = 0
idx = 0
if flag_test:

    State = list_State[idt][idx]
    plt.figure()
    plt.pcolormesh(State.lon, State.lat, State.mask)
    plt.show()

    list_config[idt][idx].EXP.flag_plot = 1
    list_config[idt][idx].INV.maxiter = 10
    list_State[idt][idx].flag_plot = 1

    inv.Inv_4Dvar(config=list_config[idt][idx], State=list_State[idt][idx], verbose=0, gpu_device=gpu_devices[0])
    list_config[idt][idx].EXP.flag_plot = config.EXP.flag_plot
    list_State[idt][idx].flag_plot = State.flag_plot
    list_config[idt][idx].INV.maxiter = config.INV.maxiter

# %%
idt = 1
idx = 0
if flag_test:

    State = list_State[idt][idx]
    plt.figure()
    plt.pcolormesh(State.lon, State.lat, State.mask)
    plt.show()

    list_config[idt][idx].EXP.flag_plot = 1
    list_config[idt][idx].INV.maxiter = 10
    list_State[idt][idx].flag_plot = 1

    inv.Inv_4Dvar(config=list_config[idt][idx], State=list_State[idt][idx], verbose=0, gpu_device=gpu_devices[0])
    list_config[idt][idx].EXP.flag_plot = config.EXP.flag_plot
    list_State[idt][idx].flag_plot = State.flag_plot
    list_config[idt][idx].INV.maxiter = config.INV.maxiter

# %%
for i, processes in enumerate(list_processes):
    print(f'*** subwindow from {list_date_start[i]} to {list_date_end[i]} ***')
    run_assimilation_time_window(config, list_date_start[i], list_date_middle[i], list_date_end[i], list_State[i], processes, 
                                 name_var_save=name_var_save,
                                 weights_space=weights_space,
                                 weights_space_sum=weights_space_sum,
                                 interpolators=interpolators,
                                 flag_assim=flag_assim, flag_merge_outputs=flag_merge_outputs, flag_diag=flag_diag, flag_overwrite_outputs=flag_overwrite_outputs,
                                 nprocs=nprocs)
# Out:
# *** subwindow from 2009-07-11 00:00:00 to 2009-08-30 00:00:00 ***
# Run subprocesses
# super: MOD_DIFF
# name_var: {'SSH': 'ssh_barotrop'}
# var_to_save: None
# name_init_var: {}
# dtmodel: 1800
# Kdiffus: 0
# SIC_mod: False
# init_from_bc: False
# dist_sponge_bc: None
#
#
# super: MOD_QG1L_JAX
# name_class: Qgm
# name_var: {'SSH': 'ssh'}
# name_init_var: {'SSH': 'ssh'}
# dir_model: None
# var_to_save: None
# save_diagnosed_variables: False
# save_params: False
# upwind: 3
# advect_pv: True
# advect_tracer: False
# dtmodel: 1800
# cfl: 0.1
# time_scheme: rk2
# c0: 2.7
# filec_aux: /home/nora/VarDyn/mapping/aux/aux_first_baroclinic_speed.nc
# name_var_c: {'lon': 'lon', 'lat': 'lat', 'var': 'c1'}
# cmin: 2.0
# cmax: None
# file_bathy_aux: None
# name_var_bathy: {'lon': '', 'lat': '', 'var': ''}
# bathy_ratio_max: None
# solver: spectral
# init_from_bc: True
# dist_sponge_bc: None
# Kdiffus: 150
# Kdiffus_trac: None
# bc_trac: OBC
# forcing_tracer_from_bc: False
# constant_c: True
# constant_f: True
# f0: None
# tile_size: 32
# tile_overlap: 16
# path_mdt: None
# name_var_mdt: None
#
# CFL condition for c= 2.4268643203051554
# Model time-step 300
#
# Observation information will be saved in dict_obs_AL_C2_H2B_J3_S3A_S3B_S6A_20090711_20090830_-33_-22_28_38_21600.txt
# Reading dict_obs_AL_C2_H2B_J3_S3A_S3B_S6A_20090711_20090830_-33_-22_28_38_21600.txt from previous run
# Basis_multi: Full JAX mode
# process observation operators
# --> 201 checkpoints to evaluate the cost function
# Running basis: <class 'src.basis.Basis_gauss3d_jax'> no_name
# lambda=1.0E+03 nlocs=6.1E+01 tdec=3.0E+00 ntime=5.4E+01 Q=1.7E-02
# reduced order: 3293184 --> 3294
#  reduced factor: 999
# Running basis: <class 'src.basis.Basis_gauss3d_jax'> no_name
# lambda=9.7E+02 nlocs=6.1E+01 tdec=2.5E+01 ntime=1.0E+01 Q=1.0E-02
# reduced order: 3293184 --> 610
#  reduced factor: 5398
# Running basis: <class 'src.basis.Basis_bmaux_jax'> no_name
# Setting Basis BMaux...
# Computing Q
# lambda=1.4E+03 nlocs=1.1E+01 tdec=2.0E+00 Q=1.0E-10
# lambda=9.7E+02 nlocs=1.4E+01 tdec=1.5E+01 Q=6.8E-04
# lambda=6.8E+02 nlocs=1.6E+01 tdec=1.3E+01 Q=1.2E-03
# lambda=4.8E+02 nlocs=2.2E+01 tdec=1.1E+01 Q=1.7E-03
# lambda=3.3E+02 nlocs=2.4E+01 tdec=9.3E+00 Q=2.1E-03
# lambda=2.3E+02 nlocs=3.3E+01 tdec=7.3E+00 Q=1.7E-03
# lambda=1.6E+02 nlocs=4.8E+01 tdec=4.6E+00 Q=1.0E-03
# lambda=1.1E+02 nlocs=6.6E+01 tdec=2.4E+00 Q=7.6E-04
# lambda=8.0E+01 nlocs=1.0E+02 tdec=2.0E+00 Q=6.3E-04
# Computing Spatial components
# Computing Time components
# reduced order: 3293184 --> 225234
#  reduced factor: 14
#
# *** Minimization ***
#
# * iteration 1 computed in 5.75E+00 second:, x=0.00E+00, J=6.08E+03, G=3.88E-01, ftol=0.00E+00, gtol=5.96E-08
# * iteration 2 computed in 5.45E+00 second:, x=-3.52E-06, J=6.55E+03, G=7.65E-01, ftol=7.14E-02, gtol=3.77E-01
# * iteration 3 computed in 5.43E+00 second:, x=-1.38E-06, J=5.75E+03, G=4.20E-01, ftol=1.22E-01, gtol=3.45E-01
# * iteration 4 computed in 5.52E+00 second:, x=-2.73E-06, J=5.43E+03, G=3.43E-01, ftol=5.50E-02, gtol=7.69E-02
# * iteration 5 computed in 5.55E+00 second:, x=-7.50E-06, J=4.89E+03, G=2.64E-01, ftol=1.00E-01, gtol=7.90E-02
# * iteration 6 computed in 5.45E+00 second:, x=-1.15E-05, J=4.60E+03, G=2.61E-01, ftol=5.92E-02, gtol=2.92E-03
# * iteration 7 computed in 6.31E+00 second:, x=-2.30E-05, J=4.05E+03, G=2.30E-01, ftol=1.20E-01, gtol=3.12E-02
# * iteration 8 computed in 6.00E+00 second:, x=-3.68E-05, J=3.72E+03, G=2.43E-01, ftol=8.19E-02, gtol=1.31E-02
# * iteration 9 computed in 5.77E+00 second:, x=-4.04E-05, J=3.44E+03, G=1.68E-01, ftol=7.52E-02, gtol=7.46E-02
# * iteration 10 computed in 6.28E+00 second:, x=-4.75E-05, J=3.19E+03, G=1.29E-01, ftol=7.10E-02, gtol=3.94E-02
# * iteration 11 computed in 5.40E+00 second:, x=-5.19E-05, J=3.08E+03, G=1.17E-01, ftol=3.41E-02, gtol=1.20E-02
# * iteration 12 computed in 5.33E+00 second:, x=-5.78E-05, J=2.93E+03, G=1.16E-01, ftol=4.95E-02, gtol=1.09E-03
# * iteration 13 computed in 5.48E+00 second:, x=-6.17E-05, J=2.88E+03, G=1.34E-01, ftol=1.80E-02, gtol=1.82E-02
# * iteration 14 computed in 5.90E+00 second:, x=-5.92E-05, J=2.78E+03, G=8.84E-02, ftol=3.25E-02, gtol=4.57E-02
# * iteration 15 computed in 5.61E+00 second:, x=-5.65E-05, J=2.74E+03, G=8.03E-02, ftol=1.63E-02, gtol=8.03E-03
# * iteration 16 computed in 6.03E+00 second:, x=-5.24E-05, J=2.68E+03, G=7.71E-02, ftol=2.16E-02, gtol=3.21E-03
# * iteration 17 computed in 6.82E+00 second:, x=-4.13E-05, J=2.67E+03, G=1.78E-01, ftol=5.07E-03, gtol=1.01E-01
# * iteration 18 computed in 7.89E+00 second:, x=-3.99E-05, J=2.59E+03, G=7.59E-02, ftol=2.80E-02, gtol=1.02E-01
# * iteration 19 computed in 8.25E+00 second:, x=-3.85E-05, J=2.57E+03, G=6.09E-02, ftol=6.93E-03, gtol=1.50E-02
# * iteration 20 computed in 7.37E+00 second:, x=-3.37E-05, J=2.56E+03, G=6.31E-02, ftol=6.67E-03, gtol=2.20E-03
# * iteration 21 computed in 7.12E+00 second:, x=-2.72E-05, J=2.53E+03, G=5.97E-02, ftol=9.31E-03, gtol=3.45E-03
# * iteration 22 computed in 7.32E+00 second:, x=-6.84E-06, J=2.50E+03, G=6.59E-02, ftol=1.27E-02, gtol=6.27E-03
# * iteration 23 computed in 8.05E+00 second:, x=-6.68E-06, J=2.48E+03, G=5.78E-02, ftol=9.32E-03, gtol=8.16E-03
# * iteration 24 computed in 7.11E+00 second:, x=-6.07E-06, J=2.46E+03, G=5.05E-02, ftol=6.12E-03, gtol=7.31E-03
# * iteration 25 computed in 6.86E+00 second:, x=-6.07E-06, J=2.45E+03, G=4.37E-02, ftol=5.89E-03, gtol=6.79E-03
# * iteration 26 computed in 7.21E+00 second:, x=-4.53E-06, J=2.43E+03, G=4.52E-02, ftol=6.37E-03, gtol=1.51E-03
# * iteration 27 computed in 7.18E+00 second:, x=-4.25E-06, J=2.41E+03, G=5.51E-02, ftol=9.31E-03, gtol=9.95E-03
# * iteration 28 computed in 7.13E+00 second:, x=-1.02E-05, J=2.39E+03, G=5.24E-02, ftol=6.55E-03, gtol=2.74E-03
# * iteration 29 computed in 7.69E+00 second:, x=-1.12E-05, J=2.38E+03, G=4.54E-02, ftol=4.52E-03, gtol=6.96E-03
# * iteration 30 computed in 8.37E+00 second:, x=-1.28E-05, J=2.38E+03, G=4.52E-02, ftol=2.82E-03, gtol=2.59E-04
# * iteration 31 computed in 7.73E+00 second:, x=-1.59E-05, J=2.37E+03, G=4.31E-02, ftol=2.33E-03, gtol=2.08E-03
# * iteration 32 computed in 7.19E+00 second:, x=-1.94E-05, J=2.36E+03, G=4.38E-02, ftol=2.93E-03, gtol=6.65E-04
# * iteration 33 computed in 7.32E+00 second:, x=-2.58E-05, J=2.35E+03, G=3.86E-02, ftol=5.18E-03, gtol=5.18E-03
# * iteration 34 computed in 7.58E+00 second:, x=-2.91E-05, J=2.34E+03, G=3.41E-02, ftol=4.35E-03, gtol=4.45E-03
# * iteration 35 computed in 6.97E+00 second:, x=-3.47E-05, J=2.33E+03, G=5.07E-02, ftol=3.85E-03, gtol=1.66E-02
# * iteration 36 computed in 6.59E+00 second:, x=-3.37E-05, J=2.32E+03, G=3.55E-02, ftol=4.56E-03, gtol=1.52E-02
# * iteration 37 computed in 6.90E+00 second:, x=-3.23E-05, J=2.32E+03, G=3.21E-02, ftol=2.05E-03, gtol=3.36E-03
# * iteration 38 computed in 6.76E+00 second:, x=-3.17E-05, J=2.31E+03, G=3.23E-02, ftol=2.65E-03, gtol=1.64E-04
# * iteration 39 computed in 6.99E+00 second:, x=-3.25E-05, J=2.30E+03, G=3.22E-02, ftol=2.98E-03, gtol=9.17E-05
# * iteration 40 computed in 7.16E+00 second:, x=-3.45E-05, J=2.30E+03, G=5.93E-02, ftol=3.47E-04, gtol=2.71E-02
# * iteration 41 computed in 8.39E+00 second:, x=-3.35E-05, J=2.30E+03, G=3.84E-02, ftol=2.16E-03, gtol=2.09E-02
# * iteration 42 computed in 8.32E+00 second:, x=-3.58E-05, J=2.29E+03, G=3.05E-02, ftol=2.70E-03, gtol=7.86E-03
# * iteration 43 computed in 7.56E+00 second:, x=-3.71E-05, J=2.29E+03, G=2.80E-02, ftol=1.27E-03, gtol=2.49E-03
# * iteration 44 computed in 8.27E+00 second:, x=-4.06E-05, J=2.29E+03, G=3.35E-02, ftol=1.36E-03, gtol=5.49E-03
# * iteration 45 computed in 8.54E+00 second:, x=-4.01E-05, J=2.28E+03, G=2.54E-02, ftol=1.63E-03, gtol=8.16E-03
# * iteration 46 computed in 8.30E+00 second:, x=-3.96E-05, J=2.28E+03, G=2.56E-02, ftol=1.05E-03, gtol=1.95E-04
# * iteration 47 computed in 8.50E+00 second:, x=-3.97E-05, J=2.28E+03, G=2.63E-02, ftol=1.50E-03, gtol=7.14E-04
# * iteration 48 computed in 7.96E+00 second:, x=-4.10E-05, J=2.27E+03, G=2.70E-02, ftol=2.42E-03, gtol=6.82E-04
# * iteration 49 computed in 8.54E+00 second:, x=-4.56E-05, J=2.27E+03, G=3.00E-02, ftol=1.87E-03, gtol=3.03E-03
# * iteration 50 computed in 8.35E+00 second:, x=-4.74E-05, J=2.26E+03, G=2.16E-02, ftol=2.09E-03, gtol=8.39E-03
# * iteration 51 computed in 8.73E+00 second:, x=-5.06E-05, J=2.26E+03, G=2.19E-02, ftol=1.56E-03, gtol=2.60E-04
# * iteration 52 computed in 9.44E+00 second:, x=-5.43E-05, J=2.26E+03, G=2.45E-02, ftol=7.22E-04, gtol=2.58E-03
# * iteration 53 computed in 8.30E+00 second:, x=-5.59E-05, J=2.26E+03, G=2.16E-02, ftol=6.52E-04, gtol=2.86E-03
# * iteration 54 computed in 7.73E+00 second:, x=-5.74E-05, J=2.26E+03, G=1.93E-02, ftol=5.62E-04, gtol=2.25E-03
# * iteration 55 computed in 7.93E+00 second:, x=-6.06E-05, J=2.25E+03, G=1.91E-02, ftol=8.91E-04, gtol=2.78E-04
# * iteration 56 computed in 8.18E+00 second:, x=-6.76E-05, J=2.25E+03, G=1.96E-02, ftol=1.60E-03, gtol=5.57E-04
# * iteration 57 computed in 8.24E+00 second:, x=-7.81E-05, J=2.25E+03, G=3.11E-02, ftol=8.28E-04, gtol=1.15E-02
# * iteration 58 computed in 9.33E+00 second:, x=-8.29E-05, J=2.24E+03, G=1.80E-02, ftol=1.45E-03, gtol=1.31E-02
# * iteration 59 computed in 9.77E+00 second:, x=-8.33E-05, J=2.24E+03, G=1.59E-02, ftol=4.02E-04, gtol=2.11E-03
# * iteration 60 computed in 9.76E+00 second:, x=-8.61E-05, J=2.24E+03, G=1.54E-02, ftol=5.45E-04, gtol=4.07E-04
# * iteration 61 computed in 9.66E+00 second:, x=-9.24E-05, J=2.24E+03, G=1.45E-02, ftol=1.05E-03, gtol=9.91E-04
# * iteration 62 computed in 9.68E+00 second:, x=-1.04E-04, J=2.24E+03, G=1.67E-02, ftol=1.13E-03, gtol=2.29E-03
# * iteration 63 computed in 9.86E+00 second:, x=-1.14E-04, J=2.24E+03, G=2.02E-02, ftol=5.59E-04, gtol=3.42E-03
# * iteration 64 computed in 9.84E+00 second:, x=-1.14E-04, J=2.24E+03, G=1.51E-02, ftol=4.79E-04, gtol=5.08E-03
# * iteration 65 computed in 9.92E+00 second:, x=-1.13E-04, J=2.24E+03, G=1.43E-02, ftol=2.23E-04, gtol=7.67E-04
# * iteration 66 computed in 1.00E+01 second:, x=-1.16E-04, J=2.23E+03, G=1.35E-02, ftol=5.78E-04, gtol=7.98E-04
# * iteration 67 computed in 9.96E+00 second:, x=-1.20E-04, J=2.23E+03, G=1.91E-02, ftol=2.90E-04, gtol=5.55E-03
# * iteration 68 computed in 9.98E+00 second:, x=-1.21E-04, J=2.23E+03, G=1.35E-02, ftol=8.04E-04, gtol=5.61E-03
# * iteration 69 computed in 9.81E+00 second:, x=-1.22E-04, J=2.23E+03, G=1.42E-02, ftol=1.59E-04, gtol=7.33E-04
# * iteration 70 computed in 9.72E+00 second:, x=-1.23E-04, J=2.23E+03, G=1.12E-02, ftol=1.85E-04, gtol=2.98E-03
# * iteration 71 computed in 9.54E+00 second:, x=-1.24E-04, J=2.23E+03, G=1.12E-02, ftol=1.37E-04, gtol=1.43E-05
# * iteration 72 computed in 9.82E+00 second:, x=-1.26E-04, J=2.23E+03, G=1.19E-02, ftol=2.35E-04, gtol=7.43E-04
# * iteration 73 computed in 9.62E+00 second:, x=-1.29E-04, J=2.23E+03, G=1.20E-02, ftol=4.75E-04, gtol=5.03E-05
# * iteration 74 computed in 9.60E+00 second:, x=-1.32E-04, J=2.23E+03, G=1.23E-02, ftol=6.39E-04, gtol=3.33E-04
# * iteration 75 computed in 9.99E+00 second:, x=-1.40E-04, J=2.23E+03, G=3.27E-02, ftol=1.47E-03, gtol=2.04E-02
# * iteration 76 computed in 9.99E+00 second:, x=-1.34E-04, J=2.23E+03, G=1.41E-02, ftol=1.70E-03, gtol=1.87E-02
# * iteration 77 computed in 1.00E+01 second:, x=-1.34E-04, J=2.23E+03, G=1.08E-02, ftol=3.22E-04, gtol=3.32E-03
# * iteration 78 computed in 9.92E+00 second:, x=-1.34E-04, J=2.23E+03, G=9.37E-03, ftol=2.07E-04, gtol=1.38E-03
# * iteration 79 computed in 1.00E+01 second:, x=-1.35E-04, J=2.23E+03, G=9.57E-03, ftol=1.71E-04, gtol=1.95E-04
# * iteration 80 computed in 9.97E+00 second:, x=-1.36E-04, J=2.22E+03, G=9.66E-03, ftol=3.55E-04, gtol=9.52E-05
# * iteration 81 computed in 9.80E+00 second:, x=-1.43E-04, J=2.23E+03, G=2.48E-02, ftol=6.37E-04, gtol=1.52E-02
# * iteration 82 computed in 9.71E+00 second:, x=-1.38E-04, J=2.22E+03, G=1.31E-02, ftol=7.93E-04, gtol=1.17E-02
# * iteration 83 computed in 9.76E+00 second:, x=-1.40E-04, J=2.22E+03, G=1.01E-02, ftol=3.57E-04, gtol=2.99E-03
# * iteration 84 computed in 9.58E+00 second:, x=-1.41E-04, J=2.22E+03, G=8.26E-03, ftol=2.26E-04, gtol=1.85E-03
# * iteration 85 computed in 9.73E+00 second:, x=-1.42E-04, J=2.22E+03, G=1.17E-02, ftol=1.14E-04, gtol=3.42E-03
# * iteration 86 computed in 9.86E+00 second:, x=-1.42E-04, J=2.22E+03, G=8.54E-03, ftol=1.35E-04, gtol=3.14E-03
# * iteration 87 computed in 9.99E+00 second:, x=-1.41E-04, J=2.22E+03, G=7.52E-03, ftol=1.21E-04, gtol=1.02E-03
# * iteration 88 computed in 1.01E+01 second:, x=-1.41E-04, J=2.22E+03, G=8.42E-03, ftol=9.12E-05, gtol=8.95E-04
# * iteration 89 computed in 1.01E+01 second:, x=-1.40E-04, J=2.22E+03, G=9.72E-03, ftol=1.51E-04, gtol=1.30E-03
# * iteration 90 computed in 9.96E+00 second:, x=-1.40E-04, J=2.22E+03, G=1.28E-02, ftol=1.10E-06, gtol=3.05E-03
# * iteration 91 computed in 9.92E+00 second:, x=-1.40E-04, J=2.22E+03, G=8.88E-03, ftol=1.30E-04, gtol=3.88E-03
# * iteration 92 computed in 9.82E+00 second:, x=-1.41E-04, J=2.22E+03, G=7.64E-03, ftol=1.50E-04, gtol=1.24E-03
# * iteration 93 computed in 9.78E+00 second:, x=-1.41E-04, J=2.22E+03, G=7.05E-03, ftol=1.24E-04, gtol=5.93E-04
# * iteration 94 computed in 9.73E+00 second:, x=-1.42E-04, J=2.22E+03, G=7.08E-03, ftol=1.58E-04, gtol=3.39E-05
# * iteration 95 computed in 1.02E+01 second:, x=-1.44E-04, J=2.22E+03, G=7.56E-03, ftol=1.76E-04, gtol=4.81E-04
# * iteration 96 computed in 1.01E+01 second:, x=-1.47E-04, J=2.22E+03, G=2.13E-02, ftol=9.15E-04, gtol=1.38E-02
# * iteration 97 computed in 9.74E+00 second:, x=-1.45E-04, J=2.22E+03, G=8.14E-03, ftol=9.97E-04, gtol=1.32E-02
# * iteration 98 computed in 9.78E+00 second:, x=-1.47E-04, J=2.22E+03, G=7.13E-03, ftol=1.46E-04, gtol=1.01E-03
# * iteration 99 computed in 9.86E+00 second:, x=-1.48E-04, J=2.22E+03, G=6.86E-03, ftol=1.33E-04, gtol=2.70E-04
# * iteration 100 computed in 9.89E+00 second:, x=-1.51E-04, J=2.22E+03, G=1.26E-02, ftol=1.61E-05, gtol=5.75E-03
# * iteration 101 computed in 9.94E+00 second:, x=-1.51E-04, J=2.22E+03, G=7.94E-03, ftol=1.53E-04, gtol=4.67E-03
# * iteration 102 computed in 9.97E+00 second:, x=-1.51E-04, J=2.22E+03, G=6.18E-03, ftol=8.30E-05, gtol=1.76E-03
# * iteration 103 computed in 9.96E+00 second:, x=-1.53E-04, J=2.22E+03, G=6.43E-03, ftol=8.84E-05, gtol=2.56E-04
# * iteration 104 computed in 9.96E+00 second:, x=-1.54E-04, J=2.22E+03, G=6.15E-03, ftol=6.30E-05, gtol=2.87E-04
# * iteration 105 computed in 9.95E+00 second:, x=-1.58E-04, J=2.22E+03, G=7.79E-03, ftol=4.45E-05, gtol=1.65E-03
# * iteration 106 computed in 9.93E+00 second:, x=-1.59E-04, J=2.22E+03, G=6.91E-03, ftol=1.03E-04, gtol=8.81E-04
# * iteration 107 computed in 9.91E+00 second:, x=-1.58E-04, J=2.22E+03, G=5.84E-03, ftol=4.70E-05, gtol=1.07E-03
# * iteration 108 computed in 9.91E+00 second:, x=-1.59E-04, J=2.22E+03, G=5.44E-03, ftol=7.28E-05, gtol=4.05E-04
# * iteration 109 computed in 9.91E+00 second:, x=-1.60E-04, J=2.22E+03, G=6.05E-03, ftol=7.05E-05, gtol=6.16E-04
# * iteration 110 computed in 9.91E+00 second:, x=-1.62E-04, J=2.22E+03, G=5.80E-03, ftol=7.97E-05, gtol=2.59E-04
# * iteration 111 computed in 9.90E+00 second:, x=-1.64E-04, J=2.22E+03, G=5.67E-03, ftol=9.53E-05, gtol=1.21E-04
# * iteration 112 computed in 9.77E+00 second:, x=-1.67E-04, J=2.22E+03, G=6.87E-03, ftol=5.65E-05, gtol=1.20E-03
# * iteration 113 computed in 9.78E+00 second:, x=-1.66E-04, J=2.22E+03, G=5.13E-03, ftol=4.47E-05, gtol=1.74E-03
# * iteration 114 computed in 9.79E+00 second:, x=-1.66E-04, J=2.22E+03, G=4.99E-03, ftol=3.76E-05, gtol=1.40E-04
# * iteration 115 computed in 9.75E+00 second:, x=-1.66E-04, J=2.22E+03, G=5.09E-03, ftol=4.77E-05, gtol=9.71E-05
# * iteration 116 computed in 9.78E+00 second:, x=-1.67E-04, J=2.22E+03, G=4.75E-03, ftol=6.37E-05, gtol=3.33E-04
# * iteration 117 computed in 9.72E+00 second:, x=-1.70E-04, J=2.22E+03, G=4.68E-03, ftol=7.87E-05, gtol=7.39E-05
# * iteration 118 computed in 9.73E+00 second:, x=-1.72E-04, J=2.22E+03, G=4.86E-03, ftol=5.74E-05, gtol=1.76E-04
# * iteration 119 computed in 9.85E+00 second:, x=-1.73E-04, J=2.22E+03, G=4.37E-03, ftol=4.21E-05, gtol=4.85E-04
# * iteration 120 computed in 9.93E+00 second:, x=-1.73E-04, J=2.22E+03, G=5.53E-03, ftol=1.51E-05, gtol=1.16E-03
# * iteration 121 computed in 9.91E+00 second:, x=-1.74E-04, J=2.22E+03, G=3.94E-03, ftol=4.05E-05, gtol=1.60E-03
# * iteration 122 computed in 9.93E+00 second:, x=-1.75E-04, J=2.22E+03, G=3.56E-03, ftol=2.16E-05, gtol=3.76E-04
# * iteration 123 computed in 9.92E+00 second:, x=-1.76E-04, J=2.22E+03, G=4.20E-03, ftol=3.31E-05, gtol=6.41E-04
# * iteration 124 computed in 9.93E+00 second:, x=-1.78E-04, J=2.22E+03, G=4.06E-03, ftol=2.96E-05, gtol=1.44E-04
# * iteration 125 computed in 9.92E+00 second:, x=-1.81E-04, J=2.22E+03, G=1.03E-02, ftol=1.05E-04, gtol=6.23E-03
# * iteration 126 computed in 1.00E+01 second:, x=-1.79E-04, J=2.22E+03, G=4.94E-03, ftol=1.18E-04, gtol=5.34E-03
# * iteration 127 computed in 9.97E+00 second:, x=-1.80E-04, J=2.22E+03, G=3.85E-03, ftol=2.44E-05, gtol=1.09E-03
# * iteration 128 computed in 9.91E+00 second:, x=-1.80E-04, J=2.22E+03, G=3.54E-03, ftol=2.03E-05, gtol=3.13E-04
# * iteration 129 computed in 9.83E+00 second:, x=-1.81E-04, J=2.22E+03, G=3.78E-03, ftol=1.63E-05, gtol=2.45E-04
# * iteration 130 computed in 9.85E+00 second:, x=-1.83E-04, J=2.22E+03, G=3.75E-03, ftol=2.57E-05, gtol=3.38E-05
# * iteration 131 computed in 9.69E+00 second:, x=-1.86E-04, J=2.22E+03, G=4.45E-03, ftol=3.07E-05, gtol=7.03E-04
# * iteration 132 computed in 9.77E+00 second:, x=-1.87E-04, J=2.22E+03, G=3.31E-03, ftol=3.57E-05, gtol=1.15E-03
# * iteration 133 computed in 9.79E+00 second:, x=-1.87E-04, J=2.22E+03, G=2.78E-03, ftol=1.27E-05, gtol=5.29E-04
# * iteration 134 computed in 9.79E+00 second:, x=-1.86E-04, J=2.22E+03, G=3.08E-03, ftol=1.23E-05, gtol=2.99E-04
# * iteration 135 computed in 9.90E+00 second:, x=-1.86E-04, J=2.22E+03, G=3.25E-03, ftol=1.15E-05, gtol=1.75E-04
# * iteration 136 computed in 1.00E+01 second:, x=-1.87E-04, J=2.22E+03, G=3.37E-03, ftol=2.87E-05, gtol=1.23E-04
# * iteration 137 computed in 9.95E+00 second:, x=-1.85E-04, J=2.22E+03, G=5.09E-03, ftol=1.62E-05, gtol=1.72E-03
# * iteration 138 computed in 9.98E+00 second:, x=-1.86E-04, J=2.22E+03, G=2.94E-03, ftol=2.80E-05, gtol=2.14E-03
# * iteration 139 computed in 1.01E+01 second:, x=-1.87E-04, J=2.22E+03, G=2.95E-03, ftol=2.13E-05, gtol=6.45E-06
# * iteration 140 computed in 1.00E+01 second:, x=-1.88E-04, J=2.21E+03, G=3.62E-03, ftol=1.10E-05, gtol=6.70E-04
# * iteration 141 computed in 9.78E+00 second:, x=-1.88E-04, J=2.21E+03, G=2.89E-03, ftol=1.20E-05, gtol=7.29E-04
# * iteration 142 computed in 9.80E+00 second:, x=-1.88E-04, J=2.21E+03, G=2.58E-03, ftol=1.37E-05, gtol=3.09E-04
# * iteration 143 computed in 9.74E+00 second:, x=-1.88E-04, J=2.21E+03, G=2.58E-03, ftol=1.87E-05, gtol=6.61E-06
# * iteration 144 computed in 9.73E+00 second:, x=-1.89E-04, J=2.21E+03, G=2.49E-03, ftol=2.62E-05, gtol=8.74E-05
# * iteration 145 computed in 9.64E+00 second:, x=-1.90E-04, J=2.21E+03, G=4.09E-03, ftol=9.92E-07, gtol=1.61E-03
# * iteration 146 computed in 9.80E+00 second:, x=-1.89E-04, J=2.21E+03, G=2.90E-03, ftol=1.38E-05, gtol=1.19E-03
# * iteration 147 computed in 9.79E+00 second:, x=-1.90E-04, J=2.21E+03, G=2.35E-03, ftol=1.93E-05, gtol=5.52E-04
# * iteration 148 computed in 9.89E+00 second:, x=-1.92E-04, J=2.21E+03, G=2.31E-03, ftol=1.68E-05, gtol=3.82E-05
# * iteration 149 computed in 9.95E+00 second:, x=-1.93E-04, J=2.21E+03, G=2.29E-03, ftol=1.41E-05, gtol=2.29E-05
# * iteration 150 computed in 1.01E+01 second:, x=-1.94E-04, J=2.21E+03, G=5.36E-03, ftol=1.79E-05, gtol=3.07E-03
# * iteration 151 computed in 1.00E+01 second:, x=-1.93E-04, J=2.21E+03, G=2.98E-03, ftol=2.31E-05, gtol=2.38E-03
#
# Is the minimization successful? True
#
# Final cost function value: 2214.679931640625
#
# Number of iterations: 140
#
# *** Saving trajectory ***
#
#
# Merge outputs
# *** subwindow from 2009-08-20 00:00:00 to 2009-10-09 00:00:00 ***
# Run subprocesses
# super: MOD_DIFF
# name_var: {'SSH': 'ssh_barotrop'}
# var_to_save: None
# name_init_var: {}
# dtmodel: 1800
# Kdiffus: 0
# SIC_mod: False
# init_from_bc: False
# dist_sponge_bc: None
#
#
# super: MOD_QG1L_JAX
# name_class: Qgm
# name_var: {'SSH': 'ssh'}
# name_init_var: {'SSH': 'ssh'}
# dir_model: None
# var_to_save: None
# save_diagnosed_variables: False
# save_params: False
# upwind: 3
# advect_pv: True
# advect_tracer: False
# dtmodel: 1800
# cfl: 0.1
# time_scheme: rk2
# c0: 2.7
# filec_aux: /home/nora/VarDyn/mapping/aux/aux_first_baroclinic_speed.nc
# name_var_c: {'lon': 'lon', 'lat': 'lat', 'var': 'c1'}
# cmin: 2.0
# cmax: None
# file_bathy_aux: None
# name_var_bathy: {'lon': '', 'lat': '', 'var': ''}
# bathy_ratio_max: None
# solver: spectral
# init_from_bc: False
# dist_sponge_bc: None
# Kdiffus: 150
# Kdiffus_trac: None
# bc_trac: OBC
# forcing_tracer_from_bc: False
# constant_c: True
# constant_f: True
# f0: None
# tile_size: 32
# tile_overlap: 16
# path_mdt: None
# name_var_mdt: None
#
# CFL condition for c= 2.4268643203051554
# Model time-step 300
#
# Observation information will be saved in dict_obs_AL_C2_H2B_J3_S3A_S3B_S6A_20090820_20091009_-33_-22_28_38_21600.txt
# Reading dict_obs_AL_C2_H2B_J3_S3A_S3B_S6A_20090820_20091009_-33_-22_28_38_21600.txt from previous run
# Basis_multi: Full JAX mode
# process observation operators
# --> 201 checkpoints to evaluate the cost function
# Running basis: <class 'src.basis.Basis_gauss3d_jax'> no_name
# lambda=1.0E+03 nlocs=6.1E+01 tdec=3.0E+00 ntime=5.4E+01 Q=1.7E-02
# reduced order: 3293184 --> 3294
#  reduced factor: 999
# Running basis: <class 'src.basis.Basis_gauss3d_jax'> no_name
# lambda=9.7E+02 nlocs=6.1E+01 tdec=2.5E+01 ntime=1.0E+01 Q=1.0E-02
# reduced order: 3293184 --> 610
#  reduced factor: 5398
# Running basis: <class 'src.basis.Basis_bmaux_jax'> no_name
# Setting Basis BMaux...
# Computing Q
# lambda=1.4E+03 nlocs=1.1E+01 tdec=2.0E+00 Q=1.0E-10
# lambda=9.7E+02 nlocs=1.4E+01 tdec=1.5E+01 Q=6.9E-04
# lambda=6.8E+02 nlocs=1.6E+01 tdec=1.3E+01 Q=1.1E-03
# lambda=4.8E+02 nlocs=2.2E+01 tdec=1.1E+01 Q=1.7E-03
# lambda=3.3E+02 nlocs=2.4E+01 tdec=9.3E+00 Q=2.2E-03
# lambda=2.3E+02 nlocs=3.3E+01 tdec=7.3E+00 Q=1.7E-03
# lambda=1.6E+02 nlocs=4.8E+01 tdec=4.6E+00 Q=9.8E-04
# lambda=1.1E+02 nlocs=6.6E+01 tdec=2.4E+00 Q=7.6E-04
# lambda=8.0E+01 nlocs=1.0E+02 tdec=2.0E+00 Q=6.3E-04
# Computing Spatial components
# Computing Time components
# reduced order: 3293184 --> 226818
#  reduced factor: 14
#
# *** Minimization ***
#
# * iteration 1 computed in 9.78E+00 second:, x=0.00E+00, J=1.12E+04, G=1.02E+00, ftol=0.00E+00, gtol=1.16E-07
# * iteration 2 computed in 9.82E+00 second:, x=-2.19E-06, J=9.01E+03, G=8.13E-01, ftol=1.98E-01, gtol=2.06E-01
# * iteration 3 computed in 9.80E+00 second:, x=-2.94E-06, J=7.86E+03, G=5.66E-01, ftol=1.28E-01, gtol=2.47E-01
# * iteration 4 computed in 9.94E+00 second:, x=-5.57E-06, J=6.84E+03, G=4.82E-01, ftol=1.30E-01, gtol=8.45E-02
# * iteration 5 computed in 9.95E+00 second:, x=-1.28E-05, J=5.41E+03, G=4.66E-01, ftol=2.10E-01, gtol=1.56E-02
# * iteration 6 computed in 9.93E+00 second:, x=-2.31E-05, J=4.56E+03, G=3.27E-01, ftol=1.58E-01, gtol=1.39E-01
# * iteration 7 computed in 1.02E+01 second:, x=-3.59E-05, J=4.10E+03, G=2.43E-01, ftol=1.00E-01, gtol=8.33E-02
# * iteration 8 computed in 1.05E+01 second:, x=-4.91E-05, J=3.83E+03, G=2.44E-01, ftol=6.44E-02, gtol=9.50E-04
# * iteration 9 computed in 9.85E+00 second:, x=-6.89E-05, J=3.55E+03, G=2.26E-01, ftol=7.46E-02, gtol=1.87E-02
# * iteration 10 computed in 9.92E+00 second:, x=-1.15E-04, J=3.09E+03, G=2.02E-01, ftol=1.29E-01, gtol=2.34E-02
# * iteration 11 computed in 9.74E+00 second:, x=-1.85E-04, J=2.76E+03, G=2.11E-01, ftol=1.07E-01, gtol=8.81E-03
# * iteration 12 computed in 9.77E+00 second:, x=-1.94E-04, J=2.63E+03, G=1.55E-01, ftol=4.76E-02, gtol=5.63E-02
# * iteration 13 computed in 9.66E+00 second:, x=-2.08E-04, J=2.54E+03, G=1.19E-01, ftol=3.35E-02, gtol=3.54E-02
# * iteration 14 computed in 9.80E+00 second:, x=-2.21E-04, J=2.48E+03, G=1.17E-01, ftol=2.49E-02, gtol=2.27E-03
# * iteration 15 computed in 9.77E+00 second:, x=-2.62E-04, J=2.32E+03, G=1.22E-01, ftol=6.25E-02, gtol=5.08E-03
# * iteration 16 computed in 9.81E+00 second:, x=-2.97E-04, J=2.19E+03, G=1.11E-01, ftol=5.79E-02, gtol=1.15E-02
# * iteration 17 computed in 9.93E+00 second:, x=-4.00E-04, J=2.62E+03, G=3.20E-01, ftol=1.64E-01, gtol=2.10E-01
# * iteration 18 computed in 9.92E+00 second:, x=-3.22E-04, J=2.14E+03, G=1.33E-01, ftol=1.83E-01, gtol=1.87E-01
# * iteration 19 computed in 9.88E+00 second:, x=-3.36E-04, J=2.05E+03, G=8.77E-02, ftol=3.85E-02, gtol=4.56E-02
# * iteration 20 computed in 9.93E+00 second:, x=-3.38E-04, J=2.03E+03, G=8.42E-02, ftol=1.42E-02, gtol=3.45E-03
# * iteration 21 computed in 9.94E+00 second:, x=-3.40E-04, J=1.99E+03, G=9.73E-02, ftol=1.97E-02, gtol=1.31E-02
# * iteration 22 computed in 9.83E+00 second:, x=-3.48E-04, J=1.94E+03, G=7.89E-02, ftol=2.15E-02, gtol=1.84E-02
# * iteration 23 computed in 9.96E+00 second:, x=-3.59E-04, J=1.91E+03, G=7.34E-02, ftol=1.74E-02, gtol=5.50E-03
# * iteration 24 computed in 9.86E+00 second:, x=-3.36E-04, J=2.13E+03, G=2.65E-01, ftol=1.02E-01, gtol=1.92E-01
# * iteration 25 computed in 9.73E+00 second:, x=-3.55E-04, J=1.90E+03, G=8.52E-02, ftol=1.09E-01, gtol=1.80E-01
# * iteration 26 computed in 9.65E+00 second:, x=-3.61E-04, J=1.87E+03, G=7.86E-02, ftol=1.26E-02, gtol=6.56E-03
# * iteration 27 computed in 9.68E+00 second:, x=-3.47E-04, J=1.84E+03, G=7.51E-02, ftol=1.86E-02, gtol=3.55E-03
# * iteration 28 computed in 9.94E+00 second:, x=-3.56E-04, J=1.80E+03, G=5.74E-02, ftol=1.76E-02, gtol=1.77E-02
# * iteration 29 computed in 9.92E+00 second:, x=-3.58E-04, J=1.78E+03, G=5.24E-02, ftol=1.33E-02, gtol=5.06E-03
# * iteration 30 computed in 9.84E+00 second:, x=-3.61E-04, J=1.75E+03, G=5.24E-02, ftol=1.68E-02, gtol=8.09E-06
# * iteration 31 computed in 9.98E+00 second:, x=-3.70E-04, J=1.76E+03, G=9.17E-02, ftol=7.04E-03, gtol=3.93E-02
# * iteration 32 computed in 1.00E+01 second:, x=-3.65E-04, J=1.74E+03, G=5.65E-02, ftol=1.41E-02, gtol=3.52E-02
# * iteration 33 computed in 9.97E+00 second:, x=-3.69E-04, J=1.72E+03, G=4.71E-02, ftol=9.46E-03, gtol=9.41E-03
# * iteration 34 computed in 9.81E+00 second:, x=-3.76E-04, J=1.71E+03, G=4.23E-02, ftol=9.33E-03, gtol=4.80E-03
# * iteration 35 computed in 9.88E+00 second:, x=-3.80E-04, J=1.70E+03, G=5.43E-02, ftol=3.72E-03, gtol=1.21E-02
# * iteration 36 computed in 9.72E+00 second:, x=-3.90E-04, J=1.69E+03, G=4.39E-02, ftol=5.24E-03, gtol=1.04E-02
# * iteration 37 computed in 9.89E+00 second:, x=-3.93E-04, J=1.68E+03, G=3.95E-02, ftol=3.24E-03, gtol=4.46E-03
# * iteration 38 computed in 9.70E+00 second:, x=-4.00E-04, J=1.68E+03, G=4.81E-02, ftol=5.49E-03, gtol=8.64E-03
# * iteration 39 computed in 9.84E+00 second:, x=-4.01E-04, J=1.67E+03, G=3.98E-02, ftol=4.14E-03, gtol=8.36E-03
# * iteration 40 computed in 9.87E+00 second:, x=-4.04E-04, J=1.66E+03, G=4.44E-02, ftol=3.50E-03, gtol=4.66E-03
# * iteration 41 computed in 9.95E+00 second:, x=-4.07E-04, J=1.66E+03, G=4.38E-02, ftol=4.05E-03, gtol=6.25E-04
# * iteration 42 computed in 1.01E+01 second:, x=-4.16E-04, J=1.64E+03, G=3.77E-02, ftol=8.52E-03, gtol=6.10E-03
# * iteration 43 computed in 1.00E+01 second:, x=-4.31E-04, J=1.63E+03, G=3.55E-02, ftol=7.58E-03, gtol=2.19E-03
# * iteration 44 computed in 1.03E+01 second:, x=-4.38E-04, J=1.62E+03, G=3.65E-02, ftol=5.68E-03, gtol=1.02E-03
# * iteration 45 computed in 1.01E+01 second:, x=-4.39E-04, J=1.61E+03, G=3.20E-02, ftol=4.45E-03, gtol=4.57E-03
# * iteration 46 computed in 1.01E+01 second:, x=-4.40E-04, J=1.60E+03, G=2.99E-02, ftol=5.00E-03, gtol=2.06E-03
# * iteration 47 computed in 1.01E+01 second:, x=-4.44E-04, J=1.62E+03, G=6.97E-02, ftol=7.15E-03, gtol=3.98E-02
# * iteration 48 computed in 9.59E+00 second:, x=-4.41E-04, J=1.60E+03, G=3.24E-02, ftol=8.88E-03, gtol=3.73E-02
# * iteration 49 computed in 1.05E+01 second:, x=-4.41E-04, J=1.60E+03, G=2.87E-02, ftol=2.64E-03, gtol=3.73E-03
# * iteration 50 computed in 1.00E+01 second:, x=-4.42E-04, J=1.59E+03, G=2.74E-02, ftol=3.59E-03, gtol=1.25E-03
# * iteration 51 computed in 9.88E+00 second:, x=-4.47E-04, J=1.59E+03, G=3.28E-02, ftol=2.72E-03, gtol=5.34E-03
# * iteration 52 computed in 9.86E+00 second:, x=-4.48E-04, J=1.58E+03, G=3.24E-02, ftol=1.78E-03, gtol=3.72E-04
# * iteration 53 computed in 9.93E+00 second:, x=-4.49E-04, J=1.58E+03, G=2.68E-02, ftol=1.18E-03, gtol=5.55E-03
# * iteration 54 computed in 9.81E+00 second:, x=-4.51E-04, J=1.58E+03, G=2.35E-02, ftol=1.84E-03, gtol=3.37E-03
# * iteration 55 computed in 9.92E+00 second:, x=-4.53E-04, J=1.58E+03, G=2.45E-02, ftol=1.52E-03, gtol=1.00E-03
# * iteration 56 computed in 1.00E+01 second:, x=-4.55E-04, J=1.57E+03, G=2.48E-02, ftol=2.97E-03, gtol=3.22E-04
# * iteration 57 computed in 1.00E+01 second:, x=-4.61E-04, J=1.58E+03, G=4.39E-02, ftol=1.30E-03, gtol=1.91E-02
# * iteration 58 computed in 9.99E+00 second:, x=-4.58E-04, J=1.57E+03, G=2.83E-02, ftol=3.20E-03, gtol=1.56E-02
# * iteration 59 computed in 9.92E+00 second:, x=-4.62E-04, J=1.57E+03, G=2.29E-02, ftol=3.12E-03, gtol=5.33E-03
# * iteration 60 computed in 9.97E+00 second:, x=-4.64E-04, J=1.56E+03, G=2.01E-02, ftol=2.24E-03, gtol=2.85E-03
# * iteration 61 computed in 9.89E+00 second:, x=-4.67E-04, J=1.56E+03, G=2.75E-02, ftol=1.76E-03, gtol=7.47E-03
# * iteration 62 computed in 9.91E+00 second:, x=-4.68E-04, J=1.56E+03, G=2.28E-02, ftol=1.30E-03, gtol=4.71E-03
# * iteration 63 computed in 9.75E+00 second:, x=-4.68E-04, J=1.56E+03, G=1.99E-02, ftol=9.69E-04, gtol=2.90E-03
# * iteration 64 computed in 9.71E+00 second:, x=-4.68E-04, J=1.55E+03, G=2.42E-02, ftol=1.44E-03, gtol=4.21E-03
# * iteration 65 computed in 9.73E+00 second:, x=-4.68E-04, J=1.55E+03, G=1.81E-02, ftol=9.69E-04, gtol=6.08E-03
# * iteration 66 computed in 9.74E+00 second:, x=-4.69E-04, J=1.55E+03, G=1.73E-02, ftol=5.28E-04, gtol=7.91E-04
# * iteration 67 computed in 9.87E+00 second:, x=-4.70E-04, J=1.55E+03, G=1.59E-02, ftol=2.14E-03, gtol=1.34E-03
# * iteration 68 computed in 9.95E+00 second:, x=-4.76E-04, J=1.55E+03, G=1.84E-02, ftol=1.49E-03, gtol=2.43E-03
# * iteration 69 computed in 1.00E+01 second:, x=-4.77E-04, J=1.54E+03, G=1.51E-02, ftol=1.58E-03, gtol=3.24E-03
# * iteration 70 computed in 1.00E+01 second:, x=-4.76E-04, J=1.54E+03, G=1.49E-02, ftol=1.24E-03, gtol=2.00E-04
# * iteration 71 computed in 9.97E+00 second:, x=-4.79E-04, J=1.54E+03, G=2.49E-02, ftol=3.76E-04, gtol=9.92E-03
# * iteration 72 computed in 9.95E+00 second:, x=-4.78E-04, J=1.54E+03, G=1.56E-02, ftol=1.63E-03, gtol=9.27E-03
# * iteration 73 computed in 9.96E+00 second:, x=-4.78E-04, J=1.54E+03, G=1.23E-02, ftol=8.04E-04, gtol=3.24E-03
# * iteration 74 computed in 9.79E+00 second:, x=-4.80E-04, J=1.54E+03, G=1.42E-02, ftol=8.04E-04, gtol=1.91E-03
# * iteration 75 computed in 9.81E+00 second:, x=-4.80E-04, J=1.54E+03, G=2.94E-02, ftol=6.06E-04, gtol=1.52E-02
# * iteration 76 computed in 9.86E+00 second:, x=-4.80E-04, J=1.53E+03, G=1.68E-02, ftol=8.75E-04, gtol=1.26E-02
# * iteration 77 computed in 9.74E+00 second:, x=-4.81E-04, J=1.53E+03, G=1.45E-02, ftol=4.24E-04, gtol=2.25E-03
# * iteration 78 computed in 9.75E+00 second:, x=-4.81E-04, J=1.53E+03, G=1.34E-02, ftol=3.01E-04, gtol=1.10E-03
# * iteration 79 computed in 9.72E+00 second:, x=-4.81E-04, J=1.53E+03, G=1.35E-02, ftol=5.82E-04, gtol=4.15E-05
# * iteration 80 computed in 9.82E+00 second:, x=-4.82E-04, J=1.53E+03, G=1.32E-02, ftol=6.35E-04, gtol=3.07E-04
# * iteration 81 computed in 1.01E+01 second:, x=-4.80E-04, J=1.53E+03, G=1.29E-02, ftol=5.28E-04, gtol=2.85E-04
# * iteration 82 computed in 1.00E+01 second:, x=-4.80E-04, J=1.53E+03, G=1.17E-02, ftol=5.16E-04, gtol=1.15E-03
# * iteration 83 computed in 1.00E+01 second:, x=-4.80E-04, J=1.53E+03, G=1.19E-02, ftol=4.85E-04, gtol=1.31E-04
# * iteration 84 computed in 1.01E+01 second:, x=-4.78E-04, J=1.53E+03, G=1.12E-02, ftol=6.43E-04, gtol=7.06E-04
# * iteration 85 computed in 9.91E+00 second:, x=-4.77E-04, J=1.53E+03, G=1.35E-02, ftol=7.66E-04, gtol=2.33E-03
# * iteration 86 computed in 9.85E+00 second:, x=-4.75E-04, J=1.53E+03, G=9.78E-03, ftol=6.34E-04, gtol=3.71E-03
# * iteration 87 computed in 9.90E+00 second:, x=-4.74E-04, J=1.53E+03, G=9.61E-03, ftol=3.76E-04, gtol=1.70E-04
# * iteration 88 computed in 9.75E+00 second:, x=-4.74E-04, J=1.53E+03, G=1.48E-02, ftol=3.05E-04, gtol=5.19E-03
# * iteration 89 computed in 9.79E+00 second:, x=-4.74E-04, J=1.52E+03, G=1.01E-02, ftol=3.45E-04, gtol=4.70E-03
# * iteration 90 computed in 9.84E+00 second:, x=-4.74E-04, J=1.52E+03, G=9.45E-03, ftol=1.80E-04, gtol=6.45E-04
# * iteration 91 computed in 1.11E+01 second:, x=-4.73E-04, J=1.52E+03, G=9.09E-03, ftol=4.73E-04, gtol=3.64E-04
# * iteration 92 computed in 9.85E+00 second:, x=-4.72E-04, J=1.52E+03, G=1.34E-02, ftol=1.53E-04, gtol=4.35E-03
# * iteration 93 computed in 9.85E+00 second:, x=-4.72E-04, J=1.52E+03, G=9.06E-03, ftol=4.34E-04, gtol=4.37E-03
# * iteration 94 computed in 9.92E+00 second:, x=-4.71E-04, J=1.52E+03, G=8.04E-03, ftol=2.09E-04, gtol=1.02E-03
# * iteration 95 computed in 9.91E+00 second:, x=-4.71E-04, J=1.52E+03, G=7.93E-03, ftol=2.10E-04, gtol=1.09E-04
# * iteration 96 computed in 9.94E+00 second:, x=-4.72E-04, J=1.52E+03, G=7.27E-03, ftol=3.08E-04, gtol=6.60E-04
# * iteration 97 computed in 9.91E+00 second:, x=-4.73E-04, J=1.52E+03, G=9.49E-03, ftol=2.94E-04, gtol=2.22E-03
# * iteration 98 computed in 9.97E+00 second:, x=-4.74E-04, J=1.52E+03, G=1.03E-02, ftol=1.42E-04, gtol=8.30E-04
# * iteration 99 computed in 9.98E+00 second:, x=-4.74E-04, J=1.52E+03, G=6.63E-03, ftol=2.24E-04, gtol=3.69E-03
# * iteration 100 computed in 9.97E+00 second:, x=-4.74E-04, J=1.52E+03, G=6.66E-03, ftol=8.23E-05, gtol=2.76E-05
# * iteration 101 computed in 9.95E+00 second:, x=-4.75E-04, J=1.52E+03, G=8.30E-03, ftol=6.52E-05, gtol=1.64E-03
# * iteration 102 computed in 1.00E+01 second:, x=-4.75E-04, J=1.52E+03, G=6.76E-03, ftol=8.97E-05, gtol=1.54E-03
# * iteration 103 computed in 9.97E+00 second:, x=-4.76E-04, J=1.52E+03, G=6.73E-03, ftol=1.03E-04, gtol=3.29E-05
# * iteration 104 computed in 9.96E+00 second:, x=-4.77E-04, J=1.52E+03, G=6.90E-03, ftol=9.36E-05, gtol=1.68E-04
# * iteration 105 computed in 9.96E+00 second:, x=-4.78E-04, J=1.52E+03, G=6.70E-03, ftol=2.24E-04, gtol=1.97E-04
# * iteration 106 computed in 9.88E+00 second:, x=-4.81E-04, J=1.52E+03, G=1.52E-02, ftol=3.45E-04, gtol=8.52E-03
# * iteration 107 computed in 9.14E+00 second:, x=-4.79E-04, J=1.52E+03, G=8.17E-03, ftol=4.62E-04, gtol=7.04E-03
# * iteration 108 computed in 9.74E+00 second:, x=-4.80E-04, J=1.52E+03, G=6.41E-03, ftol=1.93E-04, gtol=1.77E-03
# * iteration 109 computed in 9.87E+00 second:, x=-4.81E-04, J=1.52E+03, G=6.19E-03, ftol=1.21E-04, gtol=2.21E-04
# * iteration 110 computed in 9.83E+00 second:, x=-4.81E-04, J=1.52E+03, G=6.23E-03, ftol=1.42E-04, gtol=4.56E-05
# * iteration 111 computed in 9.62E+00 second:, x=-4.83E-04, J=1.52E+03, G=5.95E-03, ftol=2.16E-04, gtol=2.78E-04
# * iteration 112 computed in 9.90E+00 second:, x=-4.86E-04, J=1.52E+03, G=1.06E-02, ftol=4.56E-05, gtol=4.65E-03
# * iteration 113 computed in 9.84E+00 second:, x=-4.84E-04, J=1.52E+03, G=6.94E-03, ftol=1.55E-04, gtol=3.66E-03
# * iteration 114 computed in 9.86E+00 second:, x=-4.86E-04, J=1.52E+03, G=5.66E-03, ftol=1.56E-04, gtol=1.28E-03
# * iteration 115 computed in 9.89E+00 second:, x=-4.87E-04, J=1.52E+03, G=5.21E-03, ftol=9.15E-05, gtol=4.44E-04
# * iteration 116 computed in 9.93E+00 second:, x=-4.89E-04, J=1.52E+03, G=1.16E-02, ftol=9.91E-05, gtol=6.35E-03
# * iteration 117 computed in 9.93E+00 second:, x=-4.88E-04, J=1.52E+03, G=6.38E-03, ftol=1.52E-04, gtol=5.17E-03
# * iteration 118 computed in 9.94E+00 second:, x=-4.88E-04, J=1.52E+03, G=5.23E-03, ftol=6.00E-05, gtol=1.15E-03
# * iteration 119 computed in 9.96E+00 second:, x=-4.89E-04, J=1.52E+03, G=4.61E-03, ftol=6.78E-05, gtol=6.21E-04
# * iteration 120 computed in 1.00E+01 second:, x=-4.90E-04, J=1.52E+03, G=4.78E-03, ftol=3.72E-05, gtol=1.66E-04
# * iteration 121 computed in 1.00E+01 second:, x=-4.91E-04, J=1.52E+03, G=4.76E-03, ftol=7.66E-05, gtol=1.67E-05
# * iteration 122 computed in 9.93E+00 second:, x=-4.93E-04, J=1.52E+03, G=1.09E-02, ftol=1.86E-04, gtol=6.09E-03
# * iteration 123 computed in 9.92E+00 second:, x=-4.91E-04, J=1.52E+03, G=5.70E-03, ftol=2.20E-04, gtol=5.15E-03
# * iteration 124 computed in 9.94E+00 second:, x=-4.92E-04, J=1.52E+03, G=4.92E-03, ftol=7.34E-05, gtol=7.86E-04
# * iteration 125 computed in 9.92E+00 second:, x=-4.93E-04, J=1.52E+03, G=4.50E-03, ftol=7.08E-05, gtol=4.20E-04
# * iteration 126 computed in 9.82E+00 second:, x=-4.94E-04, J=1.52E+03, G=4.69E-03, ftol=8.08E-05, gtol=1.90E-04
# * iteration 127 computed in 9.81E+00 second:, x=-4.95E-04, J=1.52E+03, G=4.50E-03, ftol=9.10E-05, gtol=1.91E-04
# * iteration 128 computed in 9.80E+00 second:, x=-4.97E-04, J=1.52E+03, G=7.36E-03, ftol=5.63E-07, gtol=2.86E-03
# * iteration 129 computed in 9.77E+00 second:, x=-4.96E-04, J=1.52E+03, G=5.28E-03, ftol=5.27E-05, gtol=2.07E-03
# * iteration 130 computed in 9.78E+00 second:, x=-4.97E-04, J=1.52E+03, G=4.20E-03, ftol=8.42E-05, gtol=1.08E-03
# * iteration 131 computed in 9.82E+00 second:, x=-4.97E-04, J=1.52E+03, G=4.12E-03, ftol=6.04E-05, gtol=7.96E-05
# * iteration 132 computed in 9.81E+00 second:, x=-5.00E-04, J=1.52E+03, G=1.50E-02, ftol=3.46E-04, gtol=1.09E-02
# * iteration 133 computed in 9.74E+00 second:, x=-4.98E-04, J=1.52E+03, G=5.25E-03, ftol=3.75E-04, gtol=9.75E-03
# * iteration 134 computed in 9.81E+00 second:, x=-4.98E-04, J=1.52E+03, G=4.56E-03, ftol=4.64E-05, gtol=6.89E-04
# * iteration 135 computed in 9.90E+00 second:, x=-4.99E-04, J=1.52E+03, G=3.71E-03, ftol=6.86E-05, gtol=8.58E-04
# * iteration 136 computed in 9.91E+00 second:, x=-5.00E-04, J=1.52E+03, G=3.69E-03, ftol=4.56E-05, gtol=1.59E-05
# * iteration 137 computed in 9.97E+00 second:, x=-5.00E-04, J=1.52E+03, G=4.00E-03, ftol=5.25E-05, gtol=3.09E-04
# * iteration 138 computed in 9.98E+00 second:, x=-5.02E-04, J=1.52E+03, G=5.64E-03, ftol=2.72E-05, gtol=1.64E-03
# * iteration 139 computed in 9.97E+00 second:, x=-5.03E-04, J=1.52E+03, G=3.73E-03, ftol=8.57E-05, gtol=1.91E-03
# * iteration 140 computed in 1.00E+01 second:, x=-5.03E-04, J=1.52E+03, G=3.37E-03, ftol=3.16E-05, gtol=3.55E-04
# * iteration 141 computed in 9.96E+00 second:, x=-5.04E-04, J=1.52E+03, G=3.08E-03, ftol=6.44E-05, gtol=2.93E-04
# * iteration 142 computed in 1.00E+01 second:, x=-5.05E-04, J=1.52E+03, G=4.00E-03, ftol=4.03E-05, gtol=9.21E-04
# * iteration 143 computed in 1.00E+01 second:, x=-5.06E-04, J=1.52E+03, G=3.00E-03, ftol=4.90E-05, gtol=1.00E-03
# * iteration 144 computed in 9.97E+00 second:, x=-5.07E-04, J=1.52E+03, G=2.70E-03, ftol=2.38E-05, gtol=3.02E-04
# * iteration 145 computed in 9.99E+00 second:, x=-5.08E-04, J=1.52E+03, G=4.20E-03, ftol=6.36E-06, gtol=1.50E-03
#
# Is the minimization successful? True
#
# Final cost function value: 1515.9932861328125
#
# Number of iterations: 132
#
# *** Saving trajectory ***
#
#
# Merge outputs
# *** subwindow from 2009-09-29 00:00:00 to 2009-11-18 00:00:00 ***
# Run subprocesses
# super: MOD_DIFF
# name_var: {'SSH': 'ssh_barotrop'}
# var_to_save: None
# name_init_var: {}
# dtmodel: 1800
# Kdiffus: 0
# SIC_mod: False
# init_from_bc: False
# dist_sponge_bc: None
#
#
# super: MOD_QG1L_JAX
# name_class: Qgm
# name_var: {'SSH': 'ssh'}
# name_init_var: {'SSH': 'ssh'}
# dir_model: None
# var_to_save: None
# save_diagnosed_variables: False
# save_params: False
# upwind: 3
# advect_pv: True
# advect_tracer: False
# dtmodel: 1800
# cfl: 0.1
# time_scheme: rk2
# c0: 2.7
# filec_aux: /home/nora/VarDyn/mapping/aux/aux_first_baroclinic_speed.nc
# name_var_c: {'lon': 'lon', 'lat': 'lat', 'var': 'c1'}
# cmin: 2.0
# cmax: None
# file_bathy_aux: None
# name_var_bathy: {'lon': '', 'lat': '', 'var': ''}
# bathy_ratio_max: None
# solver: spectral
# init_from_bc: False
# dist_sponge_bc: None
# Kdiffus: 150
# Kdiffus_trac: None
# bc_trac: OBC
# forcing_tracer_from_bc: False
# constant_c: True
# constant_f: True
# f0: None
# tile_size: 32
# tile_overlap: 16
# path_mdt: None
# name_var_mdt: None
#
# CFL condition for c= 2.4268643203051554
# Model time-step 300
#
# Observation information will be saved in dict_obs_AL_C2_H2B_J3_S3A_S3B_S6A_20090929_20091118_-33_-22_28_38_21600.txt
# Reading dict_obs_AL_C2_H2B_J3_S3A_S3B_S6A_20090929_20091118_-33_-22_28_38_21600.txt from previous run
# Basis_multi: Full JAX mode
# process observation operators
# --> 201 checkpoints to evaluate the cost function
# Running basis: <class 'src.basis.Basis_gauss3d_jax'> no_name
# lambda=1.0E+03 nlocs=6.1E+01 tdec=3.0E+00 ntime=5.4E+01 Q=1.7E-02
# reduced order: 3293184 --> 3294
#  reduced factor: 999
# Running basis: <class 'src.basis.Basis_gauss3d_jax'> no_name
# lambda=9.7E+02 nlocs=6.1E+01 tdec=2.5E+01 ntime=1.0E+01 Q=1.0E-02
# reduced order: 3293184 --> 610
#  reduced factor: 5398
# Running basis: <class 'src.basis.Basis_bmaux_jax'> no_name
# Setting Basis BMaux...
# Computing Q
# lambda=1.4E+03 nlocs=1.1E+01 tdec=2.0E+00 Q=1.0E-10
# lambda=9.7E+02 nlocs=1.4E+01 tdec=1.5E+01 Q=7.0E-04
# lambda=6.8E+02 nlocs=1.6E+01 tdec=1.3E+01 Q=1.2E-03
# lambda=4.8E+02 nlocs=2.2E+01 tdec=1.1E+01 Q=1.6E-03
# lambda=3.3E+02 nlocs=2.4E+01 tdec=9.3E+00 Q=2.1E-03
# lambda=2.3E+02 nlocs=3.3E+01 tdec=7.3E+00 Q=1.7E-03
# lambda=1.6E+02 nlocs=4.8E+01 tdec=4.6E+00 Q=1.0E-03
# lambda=1.1E+02 nlocs=6.6E+01 tdec=2.4E+00 Q=7.4E-04
# lambda=8.0E+01 nlocs=1.0E+02 tdec=2.0E+00 Q=6.3E-04
# Computing Spatial components
# Computing Time components
# reduced order: 3293184 --> 227682
#  reduced factor: 14
#
# *** Minimization ***
#
# * iteration 1 computed in 9.76E+00 second:, x=0.00E+00, J=1.35E+04, G=8.95E-01, ftol=0.00E+00, gtol=1.79E-07
# * iteration 2 computed in 9.89E+00 second:, x=-5.16E-07, J=1.06E+04, G=7.71E-01, ftol=2.17E-01, gtol=1.24E-01
# * iteration 3 computed in 9.96E+00 second:, x=-1.48E-06, J=7.96E+03, G=5.69E-01, ftol=2.46E-01, gtol=2.02E-01
# * iteration 4 computed in 9.70E+00 second:, x=-5.59E-06, J=5.15E+03, G=3.18E-01, ftol=3.53E-01, gtol=2.51E-01
# * iteration 5 computed in 9.70E+00 second:, x=-9.23E-06, J=4.58E+03, G=2.81E-01, ftol=1.12E-01, gtol=3.71E-02
# * iteration 6 computed in 9.68E+00 second:, x=-2.02E-05, J=3.79E+03, G=2.05E-01, ftol=1.72E-01, gtol=7.56E-02
# * iteration 7 computed in 9.67E+00 second:, x=-3.37E-05, J=3.44E+03, G=2.05E-01, ftol=9.38E-02, gtol=8.10E-04
# * iteration 8 computed in 9.78E+00 second:, x=-5.62E-05, J=3.06E+03, G=1.53E-01, ftol=1.10E-01, gtol=5.18E-02
# * iteration 9 computed in 9.84E+00 second:, x=-6.80E-05, J=2.88E+03, G=1.32E-01, ftol=5.67E-02, gtol=2.09E-02
# * iteration 10 computed in 9.80E+00 second:, x=-9.31E-05, J=2.65E+03, G=1.07E-01, ftol=8.08E-02, gtol=2.45E-02
# * iteration 11 computed in 9.88E+00 second:, x=-1.24E-04, J=2.48E+03, G=1.01E-01, ftol=6.62E-02, gtol=6.27E-03
# * iteration 12 computed in 9.92E+00 second:, x=-1.77E-04, J=2.53E+03, G=1.86E-01, ftol=2.26E-02, gtol=8.47E-02
# * iteration 13 computed in 9.91E+00 second:, x=-1.47E-04, J=2.40E+03, G=1.05E-01, ftol=5.12E-02, gtol=8.06E-02
# * iteration 14 computed in 9.97E+00 second:, x=-1.64E-04, J=2.33E+03, G=8.11E-02, ftol=3.03E-02, gtol=2.41E-02
# * iteration 15 computed in 9.96E+00 second:, x=-1.78E-04, J=2.32E+03, G=1.42E-01, ftol=3.51E-03, gtol=6.06E-02
# * iteration 16 computed in 9.97E+00 second:, x=-1.80E-04, J=2.28E+03, G=8.23E-02, ftol=1.85E-02, gtol=5.94E-02
# * iteration 17 computed in 9.99E+00 second:, x=-1.83E-04, J=2.26E+03, G=7.68E-02, ftol=8.92E-03, gtol=5.57E-03
# * iteration 18 computed in 1.00E+01 second:, x=-1.93E-04, J=2.23E+03, G=8.39E-02, ftol=1.19E-02, gtol=7.13E-03
# * iteration 19 computed in 1.00E+01 second:, x=-2.06E-04, J=2.20E+03, G=7.64E-02, ftol=1.37E-02, gtol=7.46E-03
# * iteration 20 computed in 1.00E+01 second:, x=-2.48E-04, J=2.17E+03, G=7.74E-02, ftol=1.33E-02, gtol=9.74E-04
# * iteration 21 computed in 9.78E+00 second:, x=-2.60E-04, J=2.14E+03, G=7.88E-02, ftol=1.53E-02, gtol=1.40E-03
# * iteration 22 computed in 9.93E+00 second:, x=-2.60E-04, J=2.11E+03, G=6.15E-02, ftol=1.17E-02, gtol=1.72E-02
# * iteration 23 computed in 9.93E+00 second:, x=-2.72E-04, J=2.09E+03, G=5.51E-02, ftol=1.16E-02, gtol=6.40E-03
# * iteration 24 computed in 9.94E+00 second:, x=-2.99E-04, J=2.06E+03, G=5.47E-02, ftol=1.33E-02, gtol=4.06E-04
# * iteration 25 computed in 9.86E+00 second:, x=-3.52E-04, J=2.02E+03, G=5.46E-02, ftol=2.10E-02, gtol=1.92E-04
# * iteration 26 computed in 9.80E+00 second:, x=-4.26E-04, J=2.03E+03, G=9.05E-02, ftol=4.01E-03, gtol=3.60E-02
# * iteration 27 computed in 9.68E+00 second:, x=-3.84E-04, J=2.00E+03, G=5.53E-02, ftol=1.11E-02, gtol=3.53E-02
# * iteration 28 computed in 9.69E+00 second:, x=-4.10E-04, J=1.99E+03, G=4.89E-02, ftol=6.34E-03, gtol=6.35E-03
# * iteration 29 computed in 9.63E+00 second:, x=-4.14E-04, J=1.98E+03, G=4.39E-02, ftol=3.34E-03, gtol=4.97E-03
# * iteration 30 computed in 9.70E+00 second:, x=-4.16E-04, J=1.98E+03, G=4.33E-02, ftol=3.11E-03, gtol=6.63E-04
# * iteration 31 computed in 9.70E+00 second:, x=-4.57E-04, J=1.95E+03, G=4.65E-02, ftol=1.42E-02, gtol=3.19E-03
# * iteration 32 computed in 9.78E+00 second:, x=-4.77E-04, J=1.94E+03, G=4.03E-02, ftol=5.08E-03, gtol=6.15E-03
# * iteration 33 computed in 9.77E+00 second:, x=-4.83E-04, J=1.94E+03, G=3.48E-02, ftol=1.94E-03, gtol=5.51E-03
# * iteration 34 computed in 9.86E+00 second:, x=-4.93E-04, J=1.93E+03, G=3.25E-02, ftol=2.35E-03, gtol=2.29E-03
# * iteration 35 computed in 9.86E+00 second:, x=-5.09E-04, J=1.93E+03, G=3.28E-02, ftol=3.71E-03, gtol=3.26E-04
# * iteration 36 computed in 9.93E+00 second:, x=-5.39E-04, J=1.91E+03, G=3.85E-02, ftol=5.55E-03, gtol=5.68E-03
# * iteration 37 computed in 9.95E+00 second:, x=-5.62E-04, J=1.91E+03, G=3.46E-02, ftol=4.72E-03, gtol=3.90E-03
# * iteration 38 computed in 1.00E+01 second:, x=-5.64E-04, J=1.90E+03, G=2.91E-02, ftol=2.85E-03, gtol=5.57E-03
# * iteration 39 computed in 9.99E+00 second:, x=-5.62E-04, J=1.90E+03, G=3.03E-02, ftol=2.17E-03, gtol=1.23E-03
# * iteration 40 computed in 9.97E+00 second:, x=-5.62E-04, J=1.90E+03, G=5.98E-02, ftol=1.69E-03, gtol=2.95E-02
# * iteration 41 computed in 9.88E+00 second:, x=-5.62E-04, J=1.89E+03, G=3.46E-02, ftol=3.04E-03, gtol=2.53E-02
# * iteration 42 computed in 9.93E+00 second:, x=-5.66E-04, J=1.89E+03, G=3.14E-02, ftol=1.34E-03, gtol=3.14E-03
# * iteration 43 computed in 9.92E+00 second:, x=-5.88E-04, J=1.88E+03, G=2.79E-02, ftol=3.90E-03, gtol=3.51E-03
# * iteration 44 computed in 9.86E+00 second:, x=-6.00E-04, J=1.88E+03, G=2.84E-02, ftol=2.04E-03, gtol=4.66E-04
# * iteration 45 computed in 9.80E+00 second:, x=-6.28E-04, J=1.87E+03, G=2.91E-02, ftol=4.68E-03, gtol=7.57E-04
# * iteration 46 computed in 9.75E+00 second:, x=-6.50E-04, J=1.87E+03, G=4.29E-02, ftol=4.76E-05, gtol=1.38E-02
# * iteration 47 computed in 9.77E+00 second:, x=-6.39E-04, J=1.87E+03, G=3.07E-02, ftol=2.07E-03, gtol=1.22E-02
# * iteration 48 computed in 9.68E+00 second:, x=-6.48E-04, J=1.86E+03, G=2.85E-02, ftol=1.69E-03, gtol=2.14E-03
# * iteration 49 computed in 9.69E+00 second:, x=-6.49E-04, J=1.86E+03, G=2.49E-02, ftol=1.48E-03, gtol=3.62E-03
# * iteration 50 computed in 9.73E+00 second:, x=-6.53E-04, J=1.86E+03, G=2.53E-02, ftol=2.31E-03, gtol=3.82E-04
# * iteration 51 computed in 9.77E+00 second:, x=-6.59E-04, J=1.86E+03, G=2.94E-02, ftol=1.05E-03, gtol=4.12E-03
# * iteration 52 computed in 9.84E+00 second:, x=-6.62E-04, J=1.85E+03, G=2.18E-02, ftol=1.57E-03, gtol=7.66E-03
# * iteration 53 computed in 9.91E+00 second:, x=-6.69E-04, J=1.85E+03, G=2.00E-02, ftol=1.50E-03, gtol=1.76E-03
# * iteration 54 computed in 9.92E+00 second:, x=-6.77E-04, J=1.85E+03, G=2.99E-02, ftol=6.82E-04, gtol=9.89E-03
# * iteration 55 computed in 9.85E+00 second:, x=-6.81E-04, J=1.85E+03, G=2.11E-02, ftol=1.04E-03, gtol=8.84E-03
# * iteration 56 computed in 9.93E+00 second:, x=-6.82E-04, J=1.84E+03, G=2.04E-02, ftol=7.93E-04, gtol=6.54E-04
# * iteration 57 computed in 9.99E+00 second:, x=-6.82E-04, J=1.84E+03, G=2.27E-02, ftol=9.41E-04, gtol=2.29E-03
# * iteration 58 computed in 9.96E+00 second:, x=-6.82E-04, J=1.84E+03, G=2.16E-02, ftol=1.01E-03, gtol=1.04E-03
# * iteration 59 computed in 9.99E+00 second:, x=-6.82E-04, J=1.84E+03, G=2.21E-02, ftol=2.15E-03, gtol=4.09E-04
# * iteration 60 computed in 9.99E+00 second:, x=-6.86E-04, J=1.86E+03, G=6.99E-02, ftol=1.25E-02, gtol=4.78E-02
# * iteration 61 computed in 9.93E+00 second:, x=-6.83E-04, J=1.84E+03, G=2.14E-02, ftol=1.32E-02, gtol=4.84E-02
# * iteration 62 computed in 9.90E+00 second:, x=-6.85E-04, J=1.83E+03, G=1.78E-02, ftol=1.52E-03, gtol=3.63E-03
# * iteration 63 computed in 9.93E+00 second:, x=-6.87E-04, J=1.83E+03, G=1.67E-02, ftol=1.10E-03, gtol=1.14E-03
# * iteration 64 computed in 9.88E+00 second:, x=-6.89E-04, J=1.83E+03, G=1.81E-02, ftol=9.59E-04, gtol=1.42E-03
# * iteration 65 computed in 9.95E+00 second:, x=-6.94E-04, J=1.83E+03, G=1.64E-02, ftol=8.98E-04, gtol=1.65E-03
# * iteration 66 computed in 9.82E+00 second:, x=-6.95E-04, J=1.83E+03, G=1.51E-02, ftol=7.07E-04, gtol=1.37E-03
# ...
# * iteration 159 computed in 9.96E+00 second:, x=-4.76E-04, J=1.67E+03, G=2.45E-03, ftol=2.59E-05, gtol=1.75E-03
# * iteration 160 computed in 9.94E+00 second:, x=-4.76E-04, J=1.67E+03, G=2.26E-03, ftol=8.79E-06, gtol=1.85E-04
#
# Is the minimization successful? True
#
# Final cost function value: 1666.2115478515625
#
# Number of iterations: 144
#
# *** Saving trajectory ***
#
#
# Merge outputs
# *** subwindow from 2010-01-27 00:00:00 to 2010-02-25 00:00:00 ***
# Run subprocesses
# super: MOD_DIFF
# name_var: {'SSH': 'ssh_barotrop'}
# var_to_save: None
# name_init_var: {}
# dtmodel: 1800
# Kdiffus: 0
# SIC_mod: False
# init_from_bc: False
# dist_sponge_bc: None
#
#
# super: MOD_QG1L_JAX
# name_class: Qgm
# name_var: {'SSH': 'ssh'}
# name_init_var: {'SSH': 'ssh'}
# dir_model: None
# var_to_save: None
# save_diagnosed_variables: False
# save_params: False
# upwind: 3
# advect_pv: True
# advect_tracer: False
# dtmodel: 1800
# cfl: 0.1
# time_scheme: rk2
# c0: 2.7
# filec_aux: /home/nora/VarDyn/mapping/aux/aux_first_baroclinic_speed.nc
# name_var_c: {'lon': 'lon', 'lat': 'lat', 'var': 'c1'}
# cmin: 2.0
# cmax: None
# file_bathy_aux: None
# name_var_bathy: {'lon': '', 'lat': '', 'var': ''}
# bathy_ratio_max: None
# solver: spectral
# init_from_bc: False
# dist_sponge_bc: None
# Kdiffus: 150
# Kdiffus_trac: None
# bc_trac: OBC
# forcing_tracer_from_bc: False
# constant_c: True
# constant_f: True
# f0: None
# tile_size: 32
# tile_overlap: 16
# path_mdt: None
# name_var_mdt: None
#
# CFL condition for c= 2.4268643203051554
# Model time-step 300
#
# Observation information will be saved in dict_obs_AL_C2_H2B_J3_S3A_S3B_S6A_20100127_20100225_-33_-22_28_38_21600.txt
# Reading dict_obs_AL_C2_H2B_J3_S3A_S3B_S6A_20100127_20100225_-33_-22_28_38_21600.txt from previous run
# Basis_multi: Full JAX mode
# process observation operators
# --> 117 checkpoints to evaluate the cost function
# Running basis: <class 'src.basis.Basis_gauss3d_jax'> no_name
# lambda=1.0E+03 nlocs=6.1E+01 tdec=3.0E+00 ntime=3.3E+01 Q=1.7E-02
# reduced order: 1916928 --> 2013
#  reduced factor: 952
# Running basis: <class 'src.basis.Basis_gauss3d_jax'> no_name
# lambda=9.7E+02 nlocs=6.1E+01 tdec=2.5E+01 ntime=7.0E+00 Q=1.0E-02
# reduced order: 1916928 --> 427
#  reduced factor: 4489
# Running basis: <class 'src.basis.Basis_bmaux_jax'> no_name
# Setting Basis BMaux...
# Computing Q
# lambda=1.4E+03 nlocs=1.1E+01 tdec=2.0E+00 Q=1.0E-10
# lambda=9.7E+02 nlocs=1.4E+01 tdec=1.5E+01 Q=6.8E-04
# lambda=6.8E+02 nlocs=1.6E+01 tdec=1.3E+01 Q=1.0E-03
# lambda=4.8E+02 nlocs=2.2E+01 tdec=1.1E+01 Q=1.6E-03
# lambda=3.3E+02 nlocs=2.4E+01 tdec=9.3E+00 Q=2.1E-03
# lambda=2.3E+02 nlocs=3.3E+01 tdec=7.3E+00 Q=1.6E-03
# lambda=1.6E+02 nlocs=4.8E+01 tdec=4.6E+00 Q=1.1E-03
# lambda=1.1E+02 nlocs=6.6E+01 tdec=2.4E+00 Q=7.4E-04
# lambda=8.0E+01 nlocs=1.0E+02 tdec=2.0E+00 Q=6.3E-04
# Computing Spatial components
# Computing Time components
# reduced order: 1916928 --> 135918
#  reduced factor: 14
#
# *** Minimization ***
#
# * iteration 1 computed in 3.93E+00 second:, x=0.00E+00, J=7.92E+03, G=1.05E+00, ftol=0.00E+00, gtol=1.14E-07
# * iteration 2 computed in 4.95E+00 second:, x=-2.20E-07, J=5.16E+03, G=4.85E-01, ftol=3.49E-01, gtol=5.37E-01
# * iteration 3 computed in 4.52E+00 second:, x=5.09E-07, J=4.62E+03, G=4.12E-01, ftol=1.04E-01, gtol=7.28E-02
# * iteration 4 computed in 4.34E+00 second:, x=5.86E-06, J=2.83E+03, G=2.42E-01, ftol=3.87E-01, gtol=1.70E-01
# * iteration 5 computed in 4.13E+00 second:, x=9.76E-06, J=2.37E+03, G=1.96E-01, ftol=1.64E-01, gtol=4.58E-02
# * iteration 6 computed in 4.50E+00 second:, x=1.88E-05, J=1.95E+03, G=1.34E-01, ftol=1.75E-01, gtol=6.20E-02
# * iteration 7 computed in 4.82E+00 second:, x=2.66E-05, J=1.74E+03, G=1.15E-01, ftol=1.09E-01, gtol=1.91E-02
# * iteration 8 computed in 4.55E+00 second:, x=3.94E-05, J=1.53E+03, G=9.64E-02, ftol=1.22E-01, gtol=1.86E-02
# * iteration 9 computed in 4.05E+00 second:, x=5.53E-05, J=1.39E+03, G=9.09E-02, ftol=9.26E-02, gtol=5.55E-03
# * iteration 10 computed in 3.68E+00 second:, x=7.14E-05, J=1.35E+03, G=1.10E-01, ftol=2.51E-02, gtol=1.91E-02
# * iteration 11 computed in 3.37E+00 second:, x=7.03E-05, J=1.28E+03, G=6.22E-02, ftol=5.08E-02, gtol=4.78E-02
# * iteration 12 computed in 3.33E+00 second:, x=7.18E-05, J=1.26E+03, G=5.86E-02, ftol=1.82E-02, gtol=3.56E-03
# * iteration 13 computed in 4.08E+00 second:, x=7.88E-05, J=1.22E+03, G=6.21E-02, ftol=3.39E-02, gtol=3.42E-03
# * iteration 14 computed in 4.23E+00 second:, x=9.22E-05, J=1.31E+03, G=2.45E-01, ftol=7.44E-02, gtol=1.83E-01
# * iteration 15 computed in 3.96E+00 second:, x=8.22E-05, J=1.20E+03, G=8.06E-02, ftol=8.34E-02, gtol=1.65E-01
# * iteration 16 computed in 3.95E+00 second:, x=9.11E-05, J=1.17E+03, G=5.82E-02, ftol=2.52E-02, gtol=2.24E-02
# * iteration 17 computed in 4.20E+00 second:, x=9.68E-05, J=1.15E+03, G=5.14E-02, ftol=1.70E-02, gtol=6.82E-03
# * iteration 18 computed in 3.65E+00 second:, x=1.03E-04, J=1.13E+03, G=5.27E-02, ftol=2.38E-02, gtol=1.36E-03
# * iteration 19 computed in 4.28E+00 second:, x=1.10E-04, J=1.09E+03, G=5.09E-02, ftol=3.26E-02, gtol=1.78E-03
# * iteration 20 computed in 5.86E+00 second:, x=1.19E-04, J=1.10E+03, G=1.03E-01, ftol=6.15E-03, gtol=5.24E-02
# * iteration 21 computed in 5.58E+00 second:, x=1.14E-04, J=1.07E+03, G=6.25E-02, ftol=2.43E-02, gtol=4.09E-02
# * iteration 22 computed in 5.88E+00 second:, x=1.15E-04, J=1.04E+03, G=4.00E-02, ftol=2.76E-02, gtol=2.25E-02
# * iteration 23 computed in 5.64E+00 second:, x=1.14E-04, J=1.03E+03, G=3.28E-02, ftol=1.25E-02, gtol=7.17E-03
# * iteration 24 computed in 5.81E+00 second:, x=1.11E-04, J=1.01E+03, G=3.68E-02, ftol=1.55E-02, gtol=3.94E-03
# * iteration 25 computed in 5.73E+00 second:, x=1.07E-04, J=1.00E+03, G=3.52E-02, ftol=1.16E-02, gtol=1.59E-03
# * iteration 26 computed in 5.68E+00 second:, x=1.05E-04, J=9.89E+02, G=3.04E-02, ftol=1.14E-02, gtol=4.78E-03
# * iteration 27 computed in 5.83E+00 second:, x=9.75E-05, J=9.77E+02, G=5.34E-02, ftol=1.21E-02, gtol=2.29E-02
# * iteration 28 computed in 5.55E+00 second:, x=9.27E-05, J=9.75E+02, G=7.09E-02, ftol=1.67E-03, gtol=1.75E-02
# * iteration 29 computed in 5.82E+00 second:, x=9.48E-05, J=9.65E+02, G=3.54E-02, ftol=1.01E-02, gtol=3.54E-02
# * iteration 30 computed in 5.57E+00 second:, x=9.35E-05, J=9.62E+02, G=2.76E-02, ftol=3.68E-03, gtol=7.81E-03
# * iteration 31 computed in 5.86E+00 second:, x=8.81E-05, J=9.56E+02, G=2.93E-02, ftol=5.82E-03, gtol=1.66E-03
# * iteration 32 computed in 5.58E+00 second:, x=8.32E-05, J=9.52E+02, G=2.92E-02, ftol=4.27E-03, gtol=1.10E-04
# * iteration 33 computed in 5.82E+00 second:, x=6.96E-05, J=9.52E+02, G=4.81E-02, ftol=3.24E-04, gtol=1.90E-02
# * iteration 34 computed in 5.69E+00 second:, x=7.65E-05, J=9.48E+02, G=3.28E-02, ftol=4.91E-03, gtol=1.53E-02
# * iteration 35 computed in 5.71E+00 second:, x=6.99E-05, J=9.42E+02, G=2.32E-02, ftol=6.37E-03, gtol=9.60E-03
# * iteration 36 computed in 5.79E+00 second:, x=6.81E-05, J=9.39E+02, G=2.18E-02, ftol=3.41E-03, gtol=1.41E-03
# * iteration 37 computed in 5.56E+00 second:, x=6.56E-05, J=9.34E+02, G=2.39E-02, ftol=4.89E-03, gtol=2.02E-03
# * iteration 38 computed in 5.81E+00 second:, x=6.13E-05, J=9.28E+02, G=2.54E-02, ftol=6.11E-03, gtol=1.53E-03
# * iteration 39 computed in 5.62E+00 second:, x=5.30E-05, J=9.23E+02, G=2.73E-02, ftol=5.38E-03, gtol=1.90E-03
# * iteration 40 computed in 5.84E+00 second:, x=5.23E-05, J=9.19E+02, G=2.01E-02, ftol=4.66E-03, gtol=7.23E-03
# * iteration 41 computed in 5.56E+00 second:, x=5.43E-05, J=9.17E+02, G=2.51E-02, ftol=1.81E-03, gtol=5.00E-03
# * iteration 42 computed in 5.85E+00 second:, x=5.48E-05, J=9.15E+02, G=1.94E-02, ftol=2.42E-03, gtol=5.66E-03
# * iteration 43 computed in 5.65E+00 second:, x=5.52E-05, J=9.12E+02, G=2.08E-02, ftol=3.24E-03, gtol=1.45E-03
# * iteration 44 computed in 5.78E+00 second:, x=5.56E-05, J=9.10E+02, G=2.03E-02, ftol=2.58E-03, gtol=5.16E-04
# * iteration 45 computed in 5.73E+00 second:, x=5.76E-05, J=9.06E+02, G=2.21E-02, ftol=4.20E-03, gtol=1.74E-03
# * iteration 46 computed in 5.67E+00 second:, x=6.19E-05, J=9.06E+02, G=2.88E-02, ftol=5.23E-05, gtol=6.76E-03
# * iteration 47 computed in 5.80E+00 second:, x=5.97E-05, J=9.04E+02, G=1.65E-02, ftol=2.65E-03, gtol=1.23E-02
# * iteration 48 computed in 5.63E+00 second:, x=6.10E-05, J=9.02E+02, G=1.44E-02, ftol=1.68E-03, gtol=2.16E-03
# * iteration 49 computed in 5.83E+00 second:, x=6.40E-05, J=9.00E+02, G=1.36E-02, ftol=1.86E-03, gtol=7.42E-04
# * iteration 50 computed in 5.50E+00 second:, x=6.97E-05, J=8.99E+02, G=2.18E-02, ftol=1.17E-03, gtol=8.15E-03
# * iteration 51 computed in 5.85E+00 second:, x=7.19E-05, J=8.98E+02, G=1.34E-02, ftol=1.98E-03, gtol=8.36E-03
# * iteration 52 computed in 5.55E+00 second:, x=7.42E-05, J=8.97E+02, G=1.21E-02, ftol=1.04E-03, gtol=1.31E-03
# * iteration 53 computed in 5.84E+00 second:, x=7.69E-05, J=8.96E+02, G=1.26E-02, ftol=8.06E-04, gtol=5.01E-04
# * iteration 54 computed in 5.67E+00 second:, x=8.43E-05, J=8.96E+02, G=3.27E-02, ftol=4.96E-04, gtol=2.01E-02
# * iteration 55 computed in 5.71E+00 second:, x=8.01E-05, J=8.95E+02, G=1.98E-02, ftol=1.11E-03, gtol=1.30E-02
# * iteration 56 computed in 5.80E+00 second:, x=8.37E-05, J=8.94E+02, G=1.42E-02, ftol=1.16E-03, gtol=5.54E-03
# * iteration 57 computed in 5.64E+00 second:, x=8.66E-05, J=8.94E+02, G=1.08E-02, ftol=7.81E-04, gtol=3.46E-03
# * iteration 58 computed in 5.84E+00 second:, x=8.83E-05, J=8.93E+02, G=1.12E-02, ftol=4.34E-04, gtol=4.46E-04
# * iteration 59 computed in 5.52E+00 second:, x=9.04E-05, J=8.93E+02, G=1.14E-02, ftol=6.14E-04, gtol=2.13E-04
# * iteration 60 computed in 5.85E+00 second:, x=9.58E-05, J=8.92E+02, G=1.28E-02, ftol=1.15E-03, gtol=1.39E-03
# * iteration 61 computed in 5.61E+00 second:, x=1.05E-04, J=8.92E+02, G=1.75E-02, ftol=1.31E-04, gtol=4.69E-03
# * iteration 62 computed in 5.85E+00 second:, x=1.00E-04, J=8.91E+02, G=1.22E-02, ftol=6.31E-04, gtol=5.31E-03
# * iteration 63 computed in 5.65E+00 second:, x=1.02E-04, J=8.90E+02, G=1.02E-02, ftol=7.77E-04, gtol=1.96E-03
# * iteration 64 computed in 5.77E+00 second:, x=1.06E-04, J=8.89E+02, G=9.89E-03, ftol=1.12E-03, gtol=3.56E-04
# * iteration 65 computed in 5.71E+00 second:, x=1.09E-04, J=8.88E+02, G=9.74E-03, ftol=9.31E-04, gtol=1.47E-04
# * iteration 66 computed in 5.71E+00 second:, x=1.19E-04, J=8.89E+02, G=2.20E-02, ftol=1.20E-03, gtol=1.22E-02
# * iteration 67 computed in 5.79E+00 second:, x=1.12E-04, J=8.88E+02, G=1.23E-02, ftol=1.69E-03, gtol=9.66E-03
# * iteration 68 computed in 5.68E+00 second:, x=1.14E-04, J=8.87E+02, G=1.00E-02, ftol=8.67E-04, gtol=2.29E-03
# * iteration 69 computed in 5.86E+00 second:, x=1.16E-04, J=8.87E+02, G=1.14E-02, ftol=2.90E-04, gtol=1.37E-03
# * iteration 70 computed in 5.52E+00 second:, x=1.16E-04, J=8.87E+02, G=7.50E-03, ftol=3.27E-04, gtol=3.90E-03
# * iteration 71 computed in 5.95E+00 second:, x=1.15E-04, J=8.87E+02, G=8.00E-03, ftol=1.72E-04, gtol=4.98E-04
# * iteration 72 computed in 5.50E+00 second:, x=1.15E-04, J=8.86E+02, G=8.71E-03, ftol=2.75E-04, gtol=7.09E-04
# * iteration 73 computed in 5.99E+00 second:, x=1.15E-04, J=8.86E+02, G=8.27E-03, ftol=4.54E-04, gtol=4.43E-04
# * iteration 74 computed in 5.64E+00 second:, x=1.18E-04, J=8.85E+02, G=1.01E-02, ftol=5.17E-04, gtol=1.85E-03
# * iteration 75 computed in 5.83E+00 second:, x=1.19E-04, J=8.85E+02, G=1.09E-02, ftol=9.73E-05, gtol=8.25E-04
# * iteration 76 computed in 5.70E+00 second:, x=1.19E-04, J=8.85E+02, G=7.34E-03, ftol=4.16E-04, gtol=3.61E-03
# * iteration 77 computed in 5.74E+00 second:, x=1.19E-04, J=8.85E+02, G=6.19E-03, ftol=3.27E-04, gtol=1.15E-03
# * iteration 78 computed in 5.80E+00 second:, x=1.21E-04, J=8.84E+02, G=6.18E-03, ftol=4.67E-04, gtol=3.69E-06
# * iteration 79 computed in 5.62E+00 second:, x=1.21E-04, J=8.84E+02, G=6.69E-03, ftol=4.01E-04, gtol=5.08E-04
# * iteration 80 computed in 5.84E+00 second:, x=1.23E-04, J=8.84E+02, G=7.58E-03, ftol=2.61E-04, gtol=8.86E-04
# * iteration 81 computed in 5.56E+00 second:, x=1.23E-04, J=8.83E+02, G=5.35E-03, ftol=2.61E-04, gtol=2.23E-03
# * iteration 82 computed in 5.85E+00 second:, x=1.23E-04, J=8.83E+02, G=5.34E-03, ftol=1.14E-04, gtol=3.60E-06
# * iteration 83 computed in 5.52E+00 second:, x=1.23E-04, J=8.83E+02, G=8.61E-03, ftol=1.33E-04, gtol=3.27E-03
# * iteration 84 computed in 5.84E+00 second:, x=1.23E-04, J=8.83E+02, G=5.93E-03, ftol=1.95E-04, gtol=2.68E-03
# * iteration 85 computed in 5.53E+00 second:, x=1.23E-04, J=8.83E+02, G=5.12E-03, ftol=1.93E-04, gtol=8.17E-04
# * iteration 86 computed in 5.86E+00 second:, x=1.24E-04, J=8.83E+02, G=5.36E-03, ftol=1.17E-04, gtol=2.40E-04
# * iteration 87 computed in 5.69E+00 second:, x=1.26E-04, J=8.82E+02, G=5.85E-03, ftol=3.81E-04, gtol=4.91E-04
# * iteration 88 computed in 5.80E+00 second:, x=1.28E-04, J=8.82E+02, G=5.61E-03, ftol=2.54E-04, gtol=2.37E-04
# * iteration 89 computed in 5.83E+00 second:, x=1.29E-04, J=8.82E+02, G=4.36E-03, ftol=1.69E-04, gtol=1.25E-03
# * iteration 90 computed in 5.78E+00 second:, x=1.29E-04, J=8.82E+02, G=3.62E-03, ftol=1.02E-04, gtol=7.40E-04
# * iteration 91 computed in 5.88E+00 second:, x=1.30E-04, J=8.82E+02, G=3.71E-03, ftol=1.44E-04, gtol=9.40E-05
# * iteration 92 computed in 5.60E+00 second:, x=1.32E-04, J=8.82E+02, G=3.87E-03, ftol=1.46E-04, gtol=1.57E-04
# * iteration 93 computed in 5.91E+00 second:, x=1.39E-04, J=8.82E+02, G=1.16E-02, ftol=7.10E-04, gtol=7.77E-03
# * iteration 94 computed in 5.61E+00 second:, x=1.34E-04, J=8.82E+02, G=4.31E-03, ftol=7.74E-04, gtol=7.33E-03
# * iteration 95 computed in 5.99E+00 second:, x=1.37E-04, J=8.82E+02, G=3.59E-03, ftol=1.50E-04, gtol=7.23E-04
# * iteration 96 computed in 5.56E+00 second:, x=1.39E-04, J=8.81E+02, G=5.86E-03, ftol=5.50E-05, gtol=2.27E-03
# * iteration 97 computed in 5.94E+00 second:, x=1.39E-04, J=8.81E+02, G=3.77E-03, ftol=9.82E-05, gtol=2.10E-03
# * iteration 98 computed in 5.59E+00 second:, x=1.40E-04, J=8.81E+02, G=3.08E-03, ftol=6.76E-05, gtol=6.91E-04
# * iteration 99 computed in 5.91E+00 second:, x=1.41E-04, J=8.81E+02, G=3.18E-03, ftol=6.17E-05, gtol=1.03E-04
# * iteration 100 computed in 5.70E+00 second:, x=1.42E-04, J=8.81E+02, G=3.05E-03, ftol=1.02E-04, gtol=1.28E-04
# * iteration 101 computed in 5.78E+00 second:, x=1.47E-04, J=8.81E+02, G=5.26E-03, ftol=1.25E-05, gtol=2.20E-03
# * iteration 102 computed in 5.67E+00 second:, x=1.45E-04, J=8.81E+02, G=3.60E-03, ftol=6.65E-05, gtol=1.65E-03
# * iteration 103 computed in 5.77E+00 second:, x=1.46E-04, J=8.81E+02, G=2.77E-03, ftol=9.44E-05, gtol=8.27E-04
# * iteration 104 computed in 5.76E+00 second:, x=1.47E-04, J=8.81E+02, G=2.56E-03, ftol=7.36E-05, gtol=2.18E-04
# * iteration 105 computed in 5.60E+00 second:, x=1.49E-04, J=8.81E+02, G=2.66E-03, ftol=8.71E-05, gtol=1.01E-04
# * iteration 106 computed in 5.88E+00 second:, x=1.51E-04, J=8.81E+02, G=2.68E-03, ftol=7.59E-05, gtol=2.51E-05
# * iteration 107 computed in 5.61E+00 second:, x=1.53E-04, J=8.81E+02, G=6.47E-03, ftol=1.61E-04, gtol=3.78E-03
# * iteration 108 computed in 5.91E+00 second:, x=1.51E-04, J=8.81E+02, G=2.52E-03, ftol=1.86E-04, gtol=3.94E-03
# * iteration 109 computed in 5.67E+00 second:, x=1.52E-04, J=8.81E+02, G=2.18E-03, ftol=3.03E-05, gtol=3.38E-04
# * iteration 110 computed in 5.95E+00 second:, x=1.52E-04, J=8.81E+02, G=2.01E-03, ftol=3.35E-05, gtol=1.77E-04
# * iteration 111 computed in 5.59E+00 second:, x=1.52E-04, J=8.81E+02, G=2.09E-03, ftol=8.31E-05, gtol=8.71E-05
# * iteration 112 computed in 5.91E+00 second:, x=1.52E-04, J=8.81E+02, G=5.74E-03, ftol=3.39E-05, gtol=3.65E-03
# * iteration 113 computed in 5.73E+00 second:, x=1.52E-04, J=8.81E+02, G=3.05E-03, ftol=5.75E-05, gtol=2.69E-03
# * iteration 114 computed in 5.79E+00 second:, x=1.52E-04, J=8.81E+02, G=2.06E-03, ftol=5.31E-05, gtol=9.87E-04
# * iteration 115 computed in 5.83E+00 second:, x=1.52E-04, J=8.81E+02, G=1.68E-03, ftol=2.16E-05, gtol=3.80E-04
# * iteration 116 computed in 5.76E+00 second:, x=1.52E-04, J=8.81E+02, G=1.55E-03, ftol=1.87E-05, gtol=1.31E-04
# * iteration 117 computed in 5.89E+00 second:, x=1.52E-04, J=8.81E+02, G=1.66E-03, ftol=2.22E-05, gtol=1.05E-04
# * iteration 118 computed in 5.69E+00 second:, x=1.53E-04, J=8.81E+02, G=2.80E-03, ftol=9.01E-06, gtol=1.15E-03
#
# Is the minimization successful? True
#
# Final cost function value: 880.5774536132812
#
# Number of iterations: 105
#
# *** Saving trajectory ***
#
#
# Merge outputs

# %% [markdown]
# ## Merge outputs

# %%
merge_time_windows_outputs(config, list_date_start, list_date_middle, list_date_end, time_overlap)

# %% [markdown]
# ## Diagnostics

# %%
config.EXP.init_date = init_date
config.EXP.final_date = final_date

# %%
Diag = diag.Diag(config,State)
Diag.regrid_exp()
Diag.rmse_based_scores(plot=True)
Diag.psd_based_scores(plot=True)
Diag.Leaderboard()
# Out:
# super: DIAG_OSSE
# dir_output: /data2/nora/Workdir/VarDyn/diags/VarDyn-QG_eNATL60-BLB002_Azores_multiwindows
# time_min: None
# time_max: None
# time_step: None
# lon_min: None
# lon_max: None
# lat_min: None
# lat_max: None
# path_images2mp4: /data1/packages/climporn/ffmpeg/images2mp4.sh
# name_ref: /data1/data/models/eNATL60/BLB002/degraded_20/*_SSH.nc
# name_ref_time: time
# name_ref_lon: lon
# name_ref_lat: lat
# name_ref_var: ssh
# options_ref: {}
# name_exp_time: None
# name_exp_lon: None
# name_exp_lat: None
# name_exp_var: SSH_tot
# exp_grid_type: None
# compare_to_baseline: False
# name_bas: /data2/nora/Workdir/VarDyn/outputs/VarDyn-QG_eNATL60-BLB002_Azores_float32/*.nc
# name_bas_time: time
# name_bas_lon: lon
# name_bas_lat: lat
# name_bas_var: ssh
# name_mask: None
# name_var_mask: {'lon': '', 'lat': '', 'var': ''}
# /home/nora/VarDyn/mapping/src/diag.py:141: FutureWarning: The return type of `Dataset.dims` will be changed to return a set of dimension names in future, in order to be more consistent with `DataArray.dims`. To access a mapping from dimension names to lengths, please use `Dataset.sizes`.
#   self.ref_dims = list(self.ref.dims.keys())
# /home/nora/miniconda3/envs/massh_nora/lib/python3.13/site-packages/xrft/xrft.py:47: FutureWarning: Please provide the name of window adhering to scipy.signal.windows. The boolean option will be deprecated in future releases.
#   warnings.warn(
# /home/nora/miniconda3/envs/massh_nora/lib/python3.13/site-packages/xrft/xrft.py:47: FutureWarning: Please provide the name of window adhering to scipy.signal.windows. The boolean option will be deprecated in future releases.
#   warnings.warn(
#                                          Method  µ(RMSE)   σ(RMSE)  \
# 0  VarDyn-QG_eNATL60-BLB002_Azores_multiwindows      0.89     0.05
#
#    λx (degree)  λt (days)
# 0         0.91       3.18
